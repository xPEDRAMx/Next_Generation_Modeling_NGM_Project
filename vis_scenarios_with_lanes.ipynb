# %%
import math
import os
import uuid
import time

from matplotlib import cm
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import HTML
import itertools
import tensorflow as tf

# Assuming Waymo Open Dataset protos and utilities are correctly installed
try:
    from google.protobuf import text_format
    from waymo_open_dataset.protos import scenario_pb2
    # The metrics/config_util_py are for motion metrics, not parsing the core data itself
    # from waymo_open_dataset.metrics.ops import py_metrics_ops # Not strictly needed for this task
    # from waymo_open_dataset.metrics.python import config_util_py as config_util # Not strictly needed
    # from waymo_open_dataset.protos import motion_metrics_pb2 # Not strictly needed
    print("Waymo Open Dataset modules imported successfully.")
except ImportError as e:
    print(f"Error importing Waymo modules: {e}")
    print("Please ensure 'waymo-open-dataset' is installed: pip install waymo-open-dataset")
    exit()

# Define input and output directories
INPUT_DIR = '/home/hamdarlab/Desktop/Waymo/data20s/' # Adjust if your path changed
OUTPUT_DIR = '/home/hamdarlab/Desktop/Waymo/data20s/plots_scenarios_with_lanes/' # Adjusted output

# Create the output directory if it doesn't exist
try:
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    print(f"Output directory '{OUTPUT_DIR}' ensured.")
except OSError as e:
    print(f"Error creating output directory '{OUTPUT_DIR}': {e}")
    print("Please check directory permissions.")
    exit()

# --- Helper functions for distance calculation ---
def point_to_segment_distance(px, py, x1, y1, x2, y2):
    """Calculate the shortest distance from point (px, py) to line segment (x1,y1)-(x2,y2)."""
    line_mag_sq = (x2 - x1)**2 + (y2 - y1)**2
    if line_mag_sq == 0:  # Segment is a point
        return math.sqrt((px - x1)**2 + (py - y1)**2)

    u = ((px - x1) * (x2 - x1) + (py - y1) * (y2 - y1)) / line_mag_sq

    if u < 0:
        closest_x, closest_y = x1, y1
    elif u > 1:
        closest_x, closest_y = x2, y2
    else:
        closest_x = x1 + u * (x2 - x1)
        closest_y = y1 + u * (y2 - y1)
    
    return math.sqrt((px - closest_x)**2 + (py - closest_y)**2)

def point_to_polyline_distance(point_x, point_y, polyline_points):
    """Calculate the minimum distance from a point to a polyline (series of segments)."""
    min_dist = float('inf')
    if polyline_points.shape[0] == 0: # No points in polyline
        return min_dist
    if polyline_points.shape[0] == 1: # Polyline is a single point
        return math.sqrt((point_x - polyline_points[0,0])**2 + (point_y - polyline_points[0,1])**2)

    for i in range(len(polyline_points) - 1):
        x1, y1 = polyline_points[i]
        x2, y2 = polyline_points[i+1]
        dist = point_to_segment_distance(point_x, point_y, x1, y1, x2, y2)
        if dist < min_dist:
            min_dist = dist
    return min_dist

# Helper functions for plotting setup
def create_figure_and_axes(size_pixels):
  fig, ax = plt.subplots(1, 1, num=uuid.uuid4())
  dpi = 100
  size_inches = size_pixels / dpi
  fig.set_size_inches([size_inches, size_inches])
  fig.set_dpi(dpi)
  fig.set_facecolor('white')
  ax.set_facecolor('white')
  ax.xaxis.label.set_color('black')
  ax.tick_params(axis='x', colors='black')
  ax.yaxis.label.set_color('black')
  ax.tick_params(axis='y', colors='black')
  fig.set_tight_layout(True)
  ax.grid(False)
  return fig, ax


def fig_canvas_image(fig):
  fig.subplots_adjust(
      left=0.08, bottom=0.08, right=0.98, top=0.98, wspace=0.0, hspace=0.0)
  fig.canvas.draw()
  data = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8)
  return data.reshape(fig.canvas.get_width_height()[::-1] + (3,))


def get_colormap(num_agents):
  colors = cm.get_cmap('jet', num_agents)
  colors = colors(range(num_agents))
  np.random.shuffle(colors)
  return colors


def get_viewport(all_states, all_states_mask):
  valid_states = all_states[all_states_mask]
  all_y = valid_states[..., 1]
  all_x = valid_states[..., 0]

  if valid_states.size == 0:
      return 0, 0, 10 # Default to a small viewport if no valid states

  center_y = (np.max(all_y) + np.min(all_y)) / 2
  center_x = (np.max(all_x) + np.min(all_x)) / 2

  range_y = np.ptp(all_y) # Peak-to-peak range
  range_x = np.ptp(all_x)

  width = max(range_y, range_x, 10) # Ensure minimum width

  return center_y, center_x, width


# --- MODIFIED visualize_scenario_static function ---
def visualize_scenario_static(
    scenario_proto,
    size_pixels=1000,
):
    if not scenario_proto.tracks:
        print(f"    Scenario {scenario_proto.scenario_id}: No tracks found. Skipping plot.")
        return None

    total_steps = 0
    for track in scenario_proto.tracks:
        if track.states:
            total_steps = len(track.states)
            break
    
    if total_steps == 0:
        print(f"    Scenario {scenario_proto.scenario_id}: No track states found. Skipping plot.")
        return None

    vis_current_time_idx = min(99, total_steps - 1) 

    # Extract agent data
    _all_agent_states_list = []
    _all_agent_masks_list = []
    _agent_object_types_list = []
    _agent_track_ids_list = [] # To store original track.id

    for i, track in enumerate(scenario_proto.tracks):
        if len(track.states) != total_steps:
            print(f"    WARNING: Scenario {scenario_proto.scenario_id}, Track {track.id} has {len(track.states)} states, expected {total_steps}. Skipping this track for data extraction.")
            continue
        
        track_states_np = np.zeros((total_steps, 2), dtype=np.float32)
        track_masks_np = np.zeros(total_steps, dtype=bool)
        
        for array_idx, state in enumerate(track.states):
            track_states_np[array_idx, 0] = state.center_x
            track_states_np[array_idx, 1] = state.center_y
            track_masks_np[array_idx] = state.valid

        _all_agent_states_list.append(track_states_np)
        _all_agent_masks_list.append(track_masks_np)
        _agent_object_types_list.append(track.object_type)
        _agent_track_ids_list.append(track.id)
            
    if not _all_agent_states_list:
        print(f"    Scenario {scenario_proto.scenario_id}: No valid agent tracks found after filtering. Skipping plot.")
        return None

    all_agent_states = np.array(_all_agent_states_list)
    all_agent_masks = np.array(_all_agent_masks_list)
    agent_object_types = np.array(_agent_object_types_list)
    # _agent_track_ids_list is now correctly aligned with the rows of all_agent_states
    
    num_agents = all_agent_states.shape[0]

    past_states = all_agent_states[:, :vis_current_time_idx, :]
    past_states_mask = all_agent_masks[:, :vis_current_time_idx]
    current_states = all_agent_states[:, vis_current_time_idx : vis_current_time_idx + 1, :]
    current_states_mask = all_agent_masks[:, vis_current_time_idx : vis_current_time_idx + 1]
    future_states = all_agent_states[:, vis_current_time_idx + 1 :, :]
    future_states_mask = all_agent_masks[:, vis_current_time_idx + 1 :]

    # Extract roadgraph data and lane data
    roadgraph_xyz_list = []
    lanes_data = {}  # Store {lane_id: np.array([[x1,y1], [x2,y2], ...])}
    for map_feature in scenario_proto.map_features:
        feature_id = map_feature.id # Common ID for all map features
        if map_feature.HasField('lane'):
            points = []
            for point in map_feature.lane.polyline:
                roadgraph_xyz_list.append([point.x, point.y, point.z])
                points.append((point.x, point.y))
            if points:
                lanes_data[feature_id] = np.array(points)
        elif map_feature.HasField('road_line'):
            for point in map_feature.road_line.polyline:
                roadgraph_xyz_list.append([point.x, point.y, point.z])
        elif map_feature.HasField('road_edge'):
            for point in map_feature.road_edge.polyline:
                roadgraph_xyz_list.append([point.x, point.y, point.z])
        # Add other features if needed for full roadgraph visualization
        elif map_feature.HasField('stop_sign'):
            roadgraph_xyz_list.append([map_feature.stop_sign.position.x, map_feature.stop_sign.position.y, map_feature.stop_sign.position.z])
        elif map_feature.HasField('crosswalk'):
             for point in map_feature.crosswalk.polygon:
                 roadgraph_xyz_list.append([point.x, point.y, point.z])


    roadgraph_xyz = np.array(roadgraph_xyz_list, dtype=np.float32) if roadgraph_xyz_list else None

    # --- Agent to Lane Assignment ---
    agent_current_lane_ids = {} # {track_id: assigned_lane_id or None}
    LANE_ASSIGNMENT_THRESHOLD_METERS = 2.5 # Max perpendicular distance to lane centerline

    print(f"  Scenario {scenario_proto.scenario_id}: Assigning agents to lanes...")
    for agent_array_idx in range(num_agents):
        track_id = _agent_track_ids_list[agent_array_idx]
        assigned_lane_id_for_agent = None # Default to no lane

        if current_states_mask[agent_array_idx, 0]: # If agent has a valid current state
            agent_x = current_states[agent_array_idx, 0, 0]
            agent_y = current_states[agent_array_idx, 0, 1]
            
            min_dist_to_lane_center = float('inf')
            
            if not lanes_data:
                agent_current_lane_ids[track_id] = None
                continue

            for lane_id, lane_polyline_pts in lanes_data.items():
                if lane_polyline_pts.shape[0] < 2: # Need at least 2 points for a segment
                    continue
                
                dist = point_to_polyline_distance(agent_x, agent_y, lane_polyline_pts)
                
                if dist < min_dist_to_lane_center:
                    min_dist_to_lane_center = dist
                    assigned_lane_id_for_agent = lane_id
            
            if min_dist_to_lane_center <= LANE_ASSIGNMENT_THRESHOLD_METERS:
                agent_current_lane_ids[track_id] = assigned_lane_id_for_agent
                print(f"    Agent {track_id} assigned to Lane {assigned_lane_id_for_agent} (distance: {min_dist_to_lane_center:.2f}m)")
            else:
                agent_current_lane_ids[track_id] = None # Not close enough to any lane
                # print(f"    Agent {track_id} not on any lane (closest: Lane {assigned_lane_id_for_agent}, dist: {min_dist_to_lane_center:.2f}m)")
        else:
            agent_current_lane_ids[track_id] = None # No valid current state for this agent

    # --- Plotting ---
    color_map = get_colormap(num_agents)
    all_states_for_viewport = np.concatenate([past_states, current_states, future_states], axis=1)
    all_states_mask_for_viewport = np.concatenate(
        [past_states_mask, current_states_mask.reshape(num_agents, -1), future_states_mask], axis=1) # Reshape current_states_mask

    center_y, center_x, width = get_viewport(all_states_for_viewport, all_states_mask_for_viewport)
    fig, ax = create_figure_and_axes(size_pixels=size_pixels)

    # Plot roadgraph (all map features)
    if roadgraph_xyz is not None and roadgraph_xyz.size > 0:
        rg_pts = roadgraph_xyz[:, :2].T
        ax.plot(rg_pts[0, :], rg_pts[1, :], 'k.', alpha=0.2, ms=1.5) # Made fainter
    else:
        print(f"    Note: Scenario {scenario_proto.scenario_id}: No roadgraph data for general plot.")

    # Plot Lane IDs on the map
    if lanes_data:
        for lane_id, polyline_pts_array in lanes_data.items():
            if polyline_pts_array.shape[0] > 0:
                text_pos_idx = polyline_pts_array.shape[0] // 2
                text_x, text_y = polyline_pts_array[text_pos_idx]
                ax.text(text_x + 0.5, text_y + 0.5, f'L:{lane_id}', color='darkslategray', fontsize=5, ha='center', va='bottom', zorder=3, alpha=0.7)

    vehicle_marker = 'o'
    other_marker = '*'
    marker_size = 20 
    star_marker_size = 40
    line_width = 1
    alpha_value = 0.7

    for agent_idx in range(num_agents):
        agent_color = color_map[agent_idx]
        current_marker = vehicle_marker
        current_marker_size = marker_size
        if agent_object_types[agent_idx] != scenario_pb2.Track.ObjectType.TYPE_VEHICLE:
            current_marker = other_marker
            current_marker_size = star_marker_size
        
        # Plot past
        past_x = past_states[agent_idx, :, 0][past_states_mask[agent_idx, :]]
        past_y = past_states[agent_idx, :, 1][past_states_mask[agent_idx, :]]
        ax.scatter(past_x, past_y, marker=current_marker, linewidths=line_width, color=agent_color, alpha=alpha_value*0.5, s=current_marker_size*0.8, zorder=4)

        # Plot current
        if current_states_mask[agent_idx, 0]:
            current_x_val = current_states[agent_idx, 0, 0]
            current_y_val = current_states[agent_idx, 0, 1]
            ax.scatter(current_x_val, current_y_val, marker=current_marker, linewidths=line_width, color=agent_color, alpha=alpha_value, s=current_marker_size * 1.5, zorder=5, edgecolors='black',linewidth=0.5)
            # Optionally, annotate agent with its ID or assigned lane ID
            # track_id = _agent_track_ids_list[agent_idx]
            # assigned_lane = agent_current_lane_ids.get(track_id)
            # if assigned_lane is not None:
            #     ax.text(current_x_val, current_y_val + 1, f"A:{track_id}\nL:{assigned_lane}", color=agent_color, fontsize=5, zorder=6)
            # else:
            #     ax.text(current_x_val, current_y_val + 1, f"A:{track_id}", color=agent_color, fontsize=5, zorder=6)


        # Plot future
        future_x = future_states[agent_idx, :, 0][future_states_mask[agent_idx, :]]
        future_y = future_states[agent_idx, :, 1][future_states_mask[agent_idx, :]]
        ax.scatter(future_x, future_y, marker=current_marker, linewidths=line_width, color=agent_color, alpha=alpha_value*0.7, s=current_marker_size, zorder=4)

    ax.set_title(f'Scenario ID: {scenario_proto.scenario_id} - Agent Trajectories & Lane IDs (Current @ T={vis_current_time_idx})')
    plot_range = max(10, width * 1.05) # Adjusted viewport slightly
    ax.axis([
        -plot_range / 2 + center_x, plot_range / 2 + center_x, 
        -plot_range / 2 + center_y, plot_range / 2 + center_y
    ])
    ax.set_aspect('equal')

    image = fig_canvas_image(fig)
    plt.close(fig)
    return image


# --- Main script to process all files ---
print(f"\n--- Starting Plot Generation ---")
print(f"Checking input directory: {INPUT_DIR}")
print(f"Plots will be saved to: {OUTPUT_DIR}")

try:
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    print(f"Output directory '{OUTPUT_DIR}' ensured.")
except OSError as e:
    print(f"Error creating output directory '{OUTPUT_DIR}': {e}")
    print("Please check directory permissions.")
    exit()

tfrecord_files = []
for root, _, files in os.walk(INPUT_DIR):
    for f in files:
        if '.tfrecord' in f: # More robust check for tfrecord files
            tfrecord_files.append(os.path.join(root, f))

tfrecord_files.sort()

if not tfrecord_files:
    print(f"\nERROR: No TFRecord files found in '{INPUT_DIR}'.")
    print("Please double-check the 'INPUT_DIR' path and the file naming convention (e.g., '.tfrecord').")
else:
    print(f"\nFound {len(tfrecord_files)} TFRecord files to process.")
    for k, found_file in enumerate(tfrecord_files[:min(5, len(tfrecord_files))]): # Print first 5 or fewer
        print(f"  Found file {k+1}: {os.path.basename(found_file)}")
    if len(tfrecord_files) > 5:
        print("  ...")

    for i, full_filepath in enumerate(tfrecord_files):
        filename = os.path.basename(full_filepath)
        base_output_name = os.path.splitext(filename)[0] # Remove .tfrecord
        
        # It seems the original code might produce very long filenames if base_output_name already contains extensions.
        # E.g. training_20s.tfrecord-00000-of-01000 -> training_20s.tfrecord-00000-of-01000_scenario_id.png
        # This is generally fine.

        output_filepath_prefix = os.path.join(OUTPUT_DIR, base_output_name)

        print(f"\n[{i+1}/{len(tfrecord_files)}] Processing '{filename}'...")
        try:
            dataset = tf.data.TFRecordDataset(full_filepath, compression_type='')
            successful_plots_in_file = 0
            scenarios_in_file = 0

            for j, data_bytes in enumerate(dataset.as_numpy_iterator()):
                scenarios_in_file +=1
                scenario_id_for_log = "N/A"
                try:
                    scenario = scenario_pb2.Scenario()
                    scenario.ParseFromString(data_bytes)
                    scenario_id_for_log = scenario.scenario_id
                    # print(f"  Parsing scenario {j} (ID: {scenario.scenario_id})...") # Moved inside try
                    
                    plot_image = visualize_scenario_static(scenario)
                    
                    if plot_image is None or plot_image.size == 0:
                        # print(f"  - Scenario {scenario_id_for_log}: Plot image was not generated or empty. Skipping save.")
                        continue

                    scenario_output_filepath = f"{output_filepath_prefix}_scenario_{scenario.scenario_id}.png"
                    plt.imsave(scenario_output_filepath, plot_image)
                    # print(f"  - Saved plot for scenario {scenario.scenario_id} to '{scenario_output_filepath}'")
                    successful_plots_in_file += 1

                except Exception as e:
                    print(f"  - WARNING: An error occurred while processing scenario {j} (ID: {scenario_id_for_log}) in '{filename}': {e}")
                    # import traceback
                    # traceback.print_exc() # Uncomment for detailed error trace
                    continue
            
            if scenarios_in_file == 0:
                print(f"  - No scenarios found or iterated in '{filename}'.")
            elif successful_plots_in_file == 0:
                print(f"  - Processed {scenarios_in_file} scenarios in '{filename}', but none were successfully plotted.")
            else:
                print(f"  - Successfully plotted {successful_plots_in_file} out of {scenarios_in_file} scenarios from '{filename}'.")

        except tf.errors.DataLossError as e:
            print(f"  - ERROR: Data loss or corruption detected in '{filename}': {e}. Skipping this file.")
        except Exception as e:
            print(f"  - ERROR: General error loading or processing file '{filename}': {e}. Skipping this file.")
            # import traceback
            # traceback.print_exc() # Uncomment for detailed error trace


print("\n--- Plotting process complete. ---")
print(f"Check '{OUTPUT_DIR}' for generated images.")
# Out:
# 2025-05-24 14:55:43.303239: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-24 14:55:43.342741: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-24 14:55:43.343706: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-24 14:55:44.093339: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Waymo Open Dataset modules imported successfully.
# Output directory '/home/hamdarlab/Desktop/Waymo/data20s/plots_scenarios_with_lanes/' ensured.
#
# --- Starting Plot Generation ---
# Checking input directory: /home/hamdarlab/Desktop/Waymo/data20s/
# Plots will be saved to: /home/hamdarlab/Desktop/Waymo/data20s/plots_scenarios_with_lanes/
# Output directory '/home/hamdarlab/Desktop/Waymo/data20s/plots_scenarios_with_lanes/' ensured.
#
# Found 20 TFRecord files to process.
#   Found file 1: training_20s.tfrecord-00000-of-01000
#   Found file 2: training_20s.tfrecord-00001-of-01000
#   Found file 3: training_20s.tfrecord-00002-of-01000
#   Found file 4: training_20s.tfrecord-00003-of-01000
#   Found file 5: training_20s.tfrecord-00004-of-01000
#   ...
#
# [1/20] Processing 'training_20s.tfrecord-00000-of-01000'...
#   Scenario 41600af30ab8cc55: Assigning agents to lanes...
# 2025-05-24 14:55:45.405529: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
#     Agent 128 assigned to Lane 184 (distance: 0.08m)
#     Agent 129 assigned to Lane 389 (distance: 0.14m)
#     Agent 130 assigned to Lane 180 (distance: 0.06m)
#     Agent 131 assigned to Lane 183 (distance: 0.18m)
#     Agent 133 assigned to Lane 231 (distance: 0.11m)
#     Agent 135 assigned to Lane 180 (distance: 0.12m)
#     Agent 136 assigned to Lane 183 (distance: 0.28m)
#     Agent 137 assigned to Lane 389 (distance: 0.12m)
#     Agent 138 assigned to Lane 391 (distance: 0.70m)
#     Agent 139 assigned to Lane 184 (distance: 0.09m)
#     Agent 140 assigned to Lane 391 (distance: 0.05m)
#     Agent 141 assigned to Lane 184 (distance: 0.29m)
#     Agent 142 assigned to Lane 392 (distance: 0.08m)
#     Agent 144 assigned to Lane 180 (distance: 0.40m)
#     Agent 145 assigned to Lane 180 (distance: 0.03m)
#     Agent 146 assigned to Lane 184 (distance: 0.15m)
#     Agent 919 assigned to Lane 347 (distance: 0.06m)
#     Agent 105 assigned to Lane 184 (distance: 0.02m)
#     Agent 106 assigned to Lane 180 (distance: 0.18m)
#     Agent 107 assigned to Lane 184 (distance: 0.48m)
#     Agent 108 assigned to Lane 183 (distance: 0.47m)
#     Agent 109 assigned to Lane 184 (distance: 0.21m)
#     Agent 110 assigned to Lane 183 (distance: 0.33m)
#     Agent 111 assigned to Lane 373 (distance: 0.13m)
#     Agent 113 assigned to Lane 389 (distance: 0.18m)
#     Agent 117 assigned to Lane 384 (distance: 0.11m)
#     Agent 123 assigned to Lane 392 (distance: 0.26m)
#     Agent 124 assigned to Lane 231 (distance: 0.13m)
#     Agent 125 assigned to Lane 180 (distance: 0.04m)
#     Agent 920 assigned to Lane 180 (distance: 0.32m)
#   Scenario 2aa43fad083efbf3: Assigning agents to lanes...
#     Agent 2220 assigned to Lane 148 (distance: 0.43m)
#     Agent 2221 assigned to Lane 116 (distance: 0.30m)
#     Agent 2223 assigned to Lane 114 (distance: 0.37m)
#     Agent 2227 assigned to Lane 116 (distance: 0.11m)
#     Agent 2234 assigned to Lane 117 (distance: 0.10m)
#     Agent 2235 assigned to Lane 178 (distance: 0.14m)
#     Agent 2237 assigned to Lane 177 (distance: 0.04m)
#     Agent 2245 assigned to Lane 114 (distance: 0.15m)
#     Agent 2248 assigned to Lane 75 (distance: 0.11m)
#     Agent 2261 assigned to Lane 77 (distance: 0.34m)
#     Agent 2263 assigned to Lane 148 (distance: 0.23m)
#     Agent 2283 assigned to Lane 147 (distance: 0.69m)
#     Agent 2296 assigned to Lane 177 (distance: 0.22m)
#     Agent 2305 assigned to Lane 179 (distance: 0.03m)
#     Agent 2309 assigned to Lane 179 (distance: 0.20m)
#     Agent 2330 assigned to Lane 147 (distance: 0.65m)
#     Agent 2331 assigned to Lane 75 (distance: 0.14m)
#     Agent 2335 assigned to Lane 148 (distance: 0.45m)
#     Agent 2341 assigned to Lane 74 (distance: 0.03m)
#     Agent 2346 assigned to Lane 114 (distance: 0.25m)
#     Agent 2349 assigned to Lane 75 (distance: 1.25m)
#     Agent 2351 assigned to Lane 152 (distance: 0.24m)
#     Agent 2352 assigned to Lane 122 (distance: 0.26m)
#     Agent 2359 assigned to Lane 151 (distance: 0.69m)
#     Agent 2387 assigned to Lane 147 (distance: 0.42m)
#     Agent 2400 assigned to Lane 149 (distance: 0.48m)
#     Agent 2401 assigned to Lane 138 (distance: 0.40m)
#     Agent 2417 assigned to Lane 153 (distance: 0.08m)
#     Agent 2419 assigned to Lane 151 (distance: 0.21m)
#     Agent 2423 assigned to Lane 134 (distance: 0.10m)
#     Agent 2427 assigned to Lane 153 (distance: 0.47m)
#     Agent 2429 assigned to Lane 228 (distance: 0.27m)
#     Agent 2431 assigned to Lane 151 (distance: 0.05m)
#     Agent 2434 assigned to Lane 122 (distance: 0.14m)
#     Agent 2883 assigned to Lane 116 (distance: 0.13m)
#   Scenario eb073968f66914c7: Assigning agents to lanes...
#     Agent 1034 assigned to Lane 379 (distance: 0.15m)
#     Agent 1035 assigned to Lane 380 (distance: 0.31m)
#     Agent 1036 assigned to Lane 359 (distance: 1.11m)
#     Agent 1037 assigned to Lane 380 (distance: 0.09m)
#     Agent 1038 assigned to Lane 341 (distance: 0.27m)
#     Agent 1039 assigned to Lane 365 (distance: 0.73m)
#     Agent 1040 assigned to Lane 379 (distance: 0.15m)
#     Agent 1042 assigned to Lane 385 (distance: 0.05m)
#     Agent 1043 assigned to Lane 379 (distance: 0.04m)
#     Agent 1045 assigned to Lane 380 (distance: 0.56m)
#     Agent 1046 assigned to Lane 373 (distance: 0.09m)
#     Agent 1049 assigned to Lane 379 (distance: 0.26m)
#     Agent 1051 assigned to Lane 380 (distance: 0.06m)
#     Agent 1053 assigned to Lane 531 (distance: 0.34m)
#     Agent 1054 assigned to Lane 531 (distance: 0.13m)
#     Agent 1055 assigned to Lane 380 (distance: 0.28m)
#     Agent 1056 assigned to Lane 379 (distance: 0.24m)
#     Agent 1058 assigned to Lane 435 (distance: 0.31m)
#     Agent 1059 assigned to Lane 239 (distance: 0.29m)
#     Agent 1060 assigned to Lane 331 (distance: 0.49m)
#     Agent 1061 assigned to Lane 529 (distance: 0.46m)
#     Agent 1062 assigned to Lane 379 (distance: 0.12m)
#     Agent 1063 assigned to Lane 349 (distance: 0.73m)
#     Agent 1070 assigned to Lane 362 (distance: 0.01m)
#     Agent 1075 assigned to Lane 331 (distance: 0.26m)
#     Agent 1076 assigned to Lane 538 (distance: 0.25m)
#     Agent 1082 assigned to Lane 528 (distance: 0.06m)
#     Agent 1083 assigned to Lane 528 (distance: 0.57m)
#     Agent 1086 assigned to Lane 379 (distance: 0.22m)
#     Agent 1089 assigned to Lane 538 (distance: 0.32m)
#     Agent 1090 assigned to Lane 329 (distance: 0.07m)
#     Agent 1092 assigned to Lane 380 (distance: 0.12m)
#     Agent 1093 assigned to Lane 528 (distance: 0.03m)
#     Agent 1096 assigned to Lane 385 (distance: 0.43m)
#     Agent 1097 assigned to Lane 333 (distance: 0.86m)
#     Agent 1098 assigned to Lane 239 (distance: 0.35m)
#     Agent 1100 assigned to Lane 380 (distance: 0.11m)
#     Agent 1101 assigned to Lane 239 (distance: 0.25m)
#     Agent 1102 assigned to Lane 529 (distance: 0.35m)
#     Agent 1106 assigned to Lane 330 (distance: 0.62m)
#     Agent 1108 assigned to Lane 381 (distance: 0.59m)
#     Agent 1109 assigned to Lane 330 (distance: 0.12m)
#     Agent 1110 assigned to Lane 529 (distance: 0.78m)
#     Agent 1112 assigned to Lane 496 (distance: 0.34m)
#     Agent 1113 assigned to Lane 528 (distance: 0.09m)
#     Agent 1115 assigned to Lane 328 (distance: 0.09m)
#     Agent 1319 assigned to Lane 368 (distance: 0.20m)
#     Agent 1331 assigned to Lane 385 (distance: 0.14m)
#   Scenario cebdf28156152fd6: Assigning agents to lanes...
#     Agent 200 assigned to Lane 209 (distance: 0.67m)
#   Scenario e2030d66ebfe7b6b: Assigning agents to lanes...
#     Agent 721 assigned to Lane 93 (distance: 0.47m)
#     Agent 724 assigned to Lane 143 (distance: 0.17m)
#     Agent 729 assigned to Lane 142 (distance: 0.33m)
#     Agent 736 assigned to Lane 89 (distance: 0.01m)
#     Agent 739 assigned to Lane 104 (distance: 0.28m)
#     Agent 745 assigned to Lane 120 (distance: 0.22m)
#     Agent 746 assigned to Lane 133 (distance: 0.22m)
#     Agent 747 assigned to Lane 127 (distance: 0.10m)
#     Agent 748 assigned to Lane 68 (distance: 0.04m)
#     Agent 750 assigned to Lane 94 (distance: 0.22m)
#     Agent 751 assigned to Lane 120 (distance: 0.21m)
#     Agent 753 assigned to Lane 65 (distance: 0.05m)
#     Agent 754 assigned to Lane 63 (distance: 0.95m)
#     Agent 759 assigned to Lane 132 (distance: 0.19m)
#     Agent 762 assigned to Lane 94 (distance: 0.47m)
#     Agent 1018 assigned to Lane 93 (distance: 0.31m)
#   Scenario cbcf4099dfd4f9fb: Assigning agents to lanes...
#     Agent 5867 assigned to Lane 420 (distance: 1.27m)
#     Agent 5868 assigned to Lane 420 (distance: 1.56m)
#     Agent 2830 assigned to Lane 335 (distance: 0.03m)
#     Agent 2831 assigned to Lane 346 (distance: 0.08m)
#     Agent 2832 assigned to Lane 363 (distance: 0.23m)
#     Agent 2834 assigned to Lane 344 (distance: 0.06m)
#     Agent 2835 assigned to Lane 291 (distance: 0.22m)
#     Agent 2836 assigned to Lane 335 (distance: 0.36m)
#     Agent 2837 assigned to Lane 330 (distance: 0.03m)
#     Agent 2838 assigned to Lane 332 (distance: 0.36m)
#     Agent 2839 assigned to Lane 363 (distance: 0.08m)
#     Agent 2840 assigned to Lane 331 (distance: 0.00m)
#     Agent 2841 assigned to Lane 363 (distance: 0.39m)
#     Agent 2842 assigned to Lane 339 (distance: 0.57m)
#     Agent 2843 assigned to Lane 346 (distance: 0.05m)
#     Agent 2844 assigned to Lane 206 (distance: 0.86m)
#     Agent 2846 assigned to Lane 345 (distance: 0.28m)
#     Agent 2847 assigned to Lane 343 (distance: 0.06m)
#     Agent 2848 assigned to Lane 363 (distance: 0.48m)
#     Agent 2849 assigned to Lane 360 (distance: 0.24m)
#     Agent 2850 assigned to Lane 359 (distance: 0.39m)
#     Agent 2851 assigned to Lane 343 (distance: 0.14m)
#     Agent 2863 assigned to Lane 344 (distance: 0.02m)
#     Agent 2866 assigned to Lane 344 (distance: 0.22m)
#     Agent 2868 assigned to Lane 345 (distance: 0.01m)
#     Agent 2869 assigned to Lane 345 (distance: 0.12m)
#     Agent 2872 assigned to Lane 343 (distance: 0.22m)
#     Agent 2879 assigned to Lane 194 (distance: 0.01m)
#     Agent 2884 assigned to Lane 462 (distance: 0.37m)
#     Agent 2885 assigned to Lane 345 (distance: 0.03m)
#     Agent 2886 assigned to Lane 309 (distance: 0.48m)
#     Agent 2889 assigned to Lane 207 (distance: 0.58m)
#     Agent 2892 assigned to Lane 363 (distance: 0.17m)
#     Agent 2893 assigned to Lane 300 (distance: 0.08m)
#     Agent 2899 assigned to Lane 328 (distance: 0.10m)
#     Agent 2902 assigned to Lane 275 (distance: 0.15m)
#     Agent 2908 assigned to Lane 289 (distance: 0.97m)
#     Agent 2911 assigned to Lane 540 (distance: 0.06m)
#     Agent 2912 assigned to Lane 362 (distance: 0.31m)
#     Agent 2914 assigned to Lane 352 (distance: 1.31m)
#     Agent 7011 assigned to Lane 331 (distance: 0.05m)
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f237bb08b50>>
# Traceback (most recent call last):
#   File "/home/hamdarlab/anaconda3/envs/waymo-env/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
#   Scenario 96d0ccbfef0829e5: Assigning agents to lanes...
#     Agent 744 assigned to Lane 770 (distance: 0.42m)
#     Agent 745 assigned to Lane 658 (distance: 0.38m)
#     Agent 747 assigned to Lane 658 (distance: 0.13m)
#     Agent 749 assigned to Lane 761 (distance: 0.49m)
#     Agent 752 assigned to Lane 766 (distance: 1.26m)
#     Agent 791 assigned to Lane 774 (distance: 0.18m)
#     Agent 825 assigned to Lane 655 (distance: 0.00m)
#     Agent 833 assigned to Lane 771 (distance: 0.36m)
#     Agent 1110 assigned to Lane 763 (distance: 0.05m)
#   Scenario 8998493f69081ab0: Assigning agents to lanes...
#     Agent 3075 assigned to Lane 107 (distance: 1.61m)
#     Agent 3079 assigned to Lane 177 (distance: 0.56m)
#     Agent 2538 assigned to Lane 125 (distance: 1.89m)
#     Agent 2540 assigned to Lane 107 (distance: 0.68m)
#   Scenario cb3413b9e69ae5ab: Assigning agents to lanes...
#     Agent 575 assigned to Lane 518 (distance: 0.70m)
#     Agent 576 assigned to Lane 459 (distance: 0.18m)
#     Agent 578 assigned to Lane 589 (distance: 0.19m)
#     Agent 579 assigned to Lane 589 (distance: 0.56m)
#     Agent 580 assigned to Lane 589 (distance: 0.14m)
#     Agent 581 assigned to Lane 585 (distance: 0.06m)
#     Agent 582 assigned to Lane 372 (distance: 1.37m)
#     Agent 584 assigned to Lane 389 (distance: 0.81m)
#     Agent 587 assigned to Lane 391 (distance: 0.30m)
#     Agent 588 assigned to Lane 540 (distance: 0.63m)
#     Agent 589 assigned to Lane 387 (distance: 0.58m)
#     Agent 593 assigned to Lane 391 (distance: 0.22m)
#     Agent 612 assigned to Lane 589 (distance: 0.21m)
#     Agent 613 assigned to Lane 529 (distance: 0.09m)
#     Agent 726 assigned to Lane 535 (distance: 2.38m)
#     Agent 729 assigned to Lane 214 (distance: 2.18m)
#     Agent 780 assigned to Lane 583 (distance: 0.15m)
#   Scenario 7c003f7b2af6419e: Assigning agents to lanes...
#     Agent 1 assigned to Lane 230 (distance: 0.81m)
#     Agent 2 assigned to Lane 196 (distance: 0.29m)
#     Agent 4 assigned to Lane 238 (distance: 0.21m)
#     Agent 5 assigned to Lane 238 (distance: 0.07m)
#     Agent 9 assigned to Lane 196 (distance: 0.47m)
#     Agent 10 assigned to Lane 195 (distance: 0.08m)
#     Agent 12 assigned to Lane 237 (distance: 0.37m)
#     Agent 33 assigned to Lane 191 (distance: 0.01m)
#     Agent 34 assigned to Lane 195 (distance: 0.24m)
#     Agent 44 assigned to Lane 193 (distance: 0.19m)
#     Agent 62 assigned to Lane 193 (distance: 0.49m)
#     Agent 105 assigned to Lane 193 (distance: 0.08m)
#     Agent 324 assigned to Lane 196 (distance: 0.25m)
#   Scenario 2bc07893b2abbb07: Assigning agents to lanes...
#     Agent 16 assigned to Lane 260 (distance: 0.33m)
#     Agent 18 assigned to Lane 170 (distance: 1.29m)
#     Agent 20 assigned to Lane 281 (distance: 0.47m)
#     Agent 25 assigned to Lane 170 (distance: 0.82m)
#     Agent 43 assigned to Lane 257 (distance: 0.08m)
#     Agent 82 assigned to Lane 277 (distance: 0.53m)
#     Agent 199 assigned to Lane 373 (distance: 1.96m)
#     Agent 221 assigned to Lane 286 (distance: 2.48m)
#     Agent 291 assigned to Lane 301 (distance: 0.15m)
#     Agent 297 assigned to Lane 286 (distance: 0.31m)
#     Agent 301 assigned to Lane 257 (distance: 0.05m)
#     Agent 466 assigned to Lane 286 (distance: 2.26m)
#     Agent 467 assigned to Lane 169 (distance: 1.27m)
#     Agent 508 assigned to Lane 162 (distance: 0.83m)
#     Agent 703 assigned to Lane 273 (distance: 0.08m)
#   Scenario 546259711161a341: Assigning agents to lanes...
#     Agent 2190 assigned to Lane 267 (distance: 1.18m)
#     Agent 2193 assigned to Lane 228 (distance: 1.79m)
#     Agent 2194 assigned to Lane 265 (distance: 1.45m)
#     Agent 2195 assigned to Lane 258 (distance: 2.10m)
#     Agent 2198 assigned to Lane 265 (distance: 0.75m)
#     Agent 2199 assigned to Lane 257 (distance: 2.17m)
#     Agent 2200 assigned to Lane 228 (distance: 1.82m)
#     Agent 2202 assigned to Lane 265 (distance: 1.96m)
#     Agent 2206 assigned to Lane 269 (distance: 1.85m)
#     Agent 2208 assigned to Lane 228 (distance: 0.92m)
#     Agent 2224 assigned to Lane 257 (distance: 2.27m)
#     Agent 2227 assigned to Lane 269 (distance: 1.75m)
#     Agent 2234 assigned to Lane 281 (distance: 1.59m)
#     Agent 2271 assigned to Lane 281 (distance: 1.49m)
#     Agent 2291 assigned to Lane 281 (distance: 1.52m)
#     Agent 2295 assigned to Lane 258 (distance: 2.16m)
#     Agent 2298 assigned to Lane 228 (distance: 0.82m)
#     Agent 2304 assigned to Lane 281 (distance: 1.19m)
#     Agent 2305 assigned to Lane 270 (distance: 0.46m)
#     Agent 2309 assigned to Lane 281 (distance: 1.37m)
#     Agent 2319 assigned to Lane 258 (distance: 2.15m)
#     Agent 2321 assigned to Lane 378 (distance: 2.50m)
#     Agent 2323 assigned to Lane 258 (distance: 2.31m)
#     Agent 2330 assigned to Lane 281 (distance: 1.63m)
#     Agent 2331 assigned to Lane 281 (distance: 1.57m)
#     Agent 2334 assigned to Lane 281 (distance: 1.43m)
#     Agent 2341 assigned to Lane 281 (distance: 1.43m)
#     Agent 2355 assigned to Lane 281 (distance: 1.60m)
#     Agent 2375 assigned to Lane 281 (distance: 1.21m)
#     Agent 2376 assigned to Lane 281 (distance: 1.64m)
#     Agent 2377 assigned to Lane 281 (distance: 1.65m)
#     Agent 2380 assigned to Lane 281 (distance: 1.68m)
#     Agent 2386 assigned to Lane 281 (distance: 1.67m)
#     Agent 3653 assigned to Lane 273 (distance: 0.04m)
#   Scenario 9859cd1b4315b7de: Assigning agents to lanes...
#     Agent 451 assigned to Lane 658 (distance: 0.56m)
#     Agent 452 assigned to Lane 644 (distance: 0.45m)
#     Agent 453 assigned to Lane 631 (distance: 0.19m)
#     Agent 455 assigned to Lane 646 (distance: 0.10m)
#     Agent 456 assigned to Lane 633 (distance: 1.54m)
#     Agent 459 assigned to Lane 230 (distance: 0.31m)
#     Agent 460 assigned to Lane 631 (distance: 0.13m)
#     Agent 463 assigned to Lane 252 (distance: 0.74m)
#     Agent 465 assigned to Lane 615 (distance: 1.30m)
#     Agent 466 assigned to Lane 630 (distance: 0.38m)
#     Agent 476 assigned to Lane 646 (distance: 0.26m)
#     Agent 479 assigned to Lane 629 (distance: 0.09m)
#     Agent 481 assigned to Lane 252 (distance: 0.32m)
#     Agent 482 assigned to Lane 230 (distance: 0.14m)
#     Agent 483 assigned to Lane 629 (distance: 0.08m)
#     Agent 484 assigned to Lane 266 (distance: 0.01m)
#     Agent 485 assigned to Lane 620 (distance: 1.10m)
#     Agent 486 assigned to Lane 709 (distance: 0.18m)
#     Agent 487 assigned to Lane 230 (distance: 0.34m)
#     Agent 853 assigned to Lane 630 (distance: 0.02m)
#   Scenario 7ce76dd8013b8b9e: Assigning agents to lanes...
#     Agent 453 assigned to Lane 197 (distance: 0.24m)
#     Agent 454 assigned to Lane 236 (distance: 0.04m)
#     Agent 455 assigned to Lane 234 (distance: 0.46m)
#     Agent 456 assigned to Lane 245 (distance: 0.29m)
#     Agent 457 assigned to Lane 282 (distance: 0.34m)
#     Agent 458 assigned to Lane 233 (distance: 0.60m)
#     Agent 459 assigned to Lane 228 (distance: 0.08m)
#     Agent 460 assigned to Lane 222 (distance: 0.35m)
#     Agent 461 assigned to Lane 219 (distance: 2.07m)
#     Agent 462 assigned to Lane 220 (distance: 0.58m)
#     Agent 464 assigned to Lane 224 (distance: 0.21m)
#     Agent 465 assigned to Lane 216 (distance: 0.46m)
#     Agent 685 assigned to Lane 197 (distance: 0.04m)
#   Scenario 9ec70bf90d6fe529: Assigning agents to lanes...
#     Agent 1306 assigned to Lane 120 (distance: 0.02m)
#     Agent 1308 assigned to Lane 120 (distance: 0.03m)
#     Agent 1310 assigned to Lane 110 (distance: 0.12m)
#     Agent 1313 assigned to Lane 61 (distance: 0.23m)
#     Agent 1610 assigned to Lane 148 (distance: 1.77m)
#   Scenario df74ad0cc6823304: Assigning agents to lanes...
#     Agent 641 assigned to Lane 120 (distance: 1.48m)
#     Agent 206 assigned to Lane 459 (distance: 0.11m)
#     Agent 208 assigned to Lane 460 (distance: 0.23m)
#     Agent 212 assigned to Lane 459 (distance: 0.23m)
#     Agent 214 assigned to Lane 114 (distance: 0.34m)
#     Agent 215 assigned to Lane 125 (distance: 0.06m)
#     Agent 216 assigned to Lane 313 (distance: 0.88m)
#     Agent 217 assigned to Lane 196 (distance: 0.18m)
#     Agent 219 assigned to Lane 129 (distance: 0.38m)
#     Agent 220 assigned to Lane 124 (distance: 0.14m)
#     Agent 221 assigned to Lane 196 (distance: 0.05m)
#     Agent 222 assigned to Lane 324 (distance: 0.08m)
#     Agent 225 assigned to Lane 287 (distance: 0.05m)
#     Agent 226 assigned to Lane 286 (distance: 0.03m)
#     Agent 227 assigned to Lane 132 (distance: 0.36m)
#     Agent 228 assigned to Lane 137 (distance: 0.63m)
#     Agent 229 assigned to Lane 126 (distance: 0.24m)
#     Agent 230 assigned to Lane 196 (distance: 0.13m)
#     Agent 231 assigned to Lane 336 (distance: 0.42m)
#     Agent 656 assigned to Lane 460 (distance: 0.38m)
#   Scenario 7f94d7eac202a8f6: Assigning agents to lanes...
#     Agent 4235 assigned to Lane 103 (distance: 1.41m)
#     Agent 3515 assigned to Lane 105 (distance: 0.24m)
#     Agent 3516 assigned to Lane 119 (distance: 0.69m)
#     Agent 3533 assigned to Lane 131 (distance: 0.88m)
#     Agent 3537 assigned to Lane 116 (distance: 0.35m)
#     Agent 3539 assigned to Lane 127 (distance: 0.08m)
#     Agent 3541 assigned to Lane 118 (distance: 0.15m)
#     Agent 3545 assigned to Lane 118 (distance: 0.21m)
#     Agent 3547 assigned to Lane 124 (distance: 0.14m)
#     Agent 4239 assigned to Lane 86 (distance: 0.04m)
#   Scenario b29b20e997b76ea3: Assigning agents to lanes...
#     Agent 1025 assigned to Lane 203 (distance: 2.07m)
#     Agent 1027 assigned to Lane 190 (distance: 1.54m)
#     Agent 1028 assigned to Lane 207 (distance: 1.69m)
#     Agent 1030 assigned to Lane 227 (distance: 1.96m)
#     Agent 1034 assigned to Lane 190 (distance: 2.26m)
#     Agent 1035 assigned to Lane 190 (distance: 1.57m)
#     Agent 1036 assigned to Lane 227 (distance: 2.14m)
#     Agent 1037 assigned to Lane 172 (distance: 0.03m)
#     Agent 1039 assigned to Lane 203 (distance: 2.09m)
#     Agent 1041 assigned to Lane 172 (distance: 0.27m)
#     Agent 1042 assigned to Lane 171 (distance: 0.07m)
#     Agent 1044 assigned to Lane 171 (distance: 0.25m)
#     Agent 1046 assigned to Lane 185 (distance: 2.22m)
#     Agent 1048 assigned to Lane 137 (distance: 2.33m)
#     Agent 1050 assigned to Lane 174 (distance: 0.04m)
#     Agent 1051 assigned to Lane 174 (distance: 0.13m)
#     Agent 1052 assigned to Lane 173 (distance: 0.13m)
#     Agent 1054 assigned to Lane 173 (distance: 0.12m)
#     Agent 1055 assigned to Lane 174 (distance: 0.04m)
#     Agent 1057 assigned to Lane 227 (distance: 2.47m)
#     Agent 1059 assigned to Lane 187 (distance: 2.20m)
#     Agent 978 assigned to Lane 195 (distance: 0.18m)
#     Agent 979 assigned to Lane 213 (distance: 0.20m)
#     Agent 980 assigned to Lane 195 (distance: 0.11m)
#     Agent 981 assigned to Lane 213 (distance: 0.24m)
#     Agent 982 assigned to Lane 195 (distance: 0.12m)
#     Agent 984 assigned to Lane 213 (distance: 0.10m)
#     Agent 986 assigned to Lane 194 (distance: 0.50m)
#     Agent 987 assigned to Lane 195 (distance: 0.01m)
#     Agent 991 assigned to Lane 195 (distance: 0.32m)
#     Agent 992 assigned to Lane 195 (distance: 0.09m)
#     Agent 1001 assigned to Lane 207 (distance: 1.54m)
#     Agent 1003 assigned to Lane 227 (distance: 2.09m)
#     Agent 1007 assigned to Lane 203 (distance: 1.28m)
#     Agent 1008 assigned to Lane 172 (distance: 0.11m)
#     Agent 1010 assigned to Lane 172 (distance: 0.10m)
#     Agent 1015 assigned to Lane 207 (distance: 1.53m)
#     Agent 1018 assigned to Lane 227 (distance: 1.92m)
#     Agent 1019 assigned to Lane 190 (distance: 1.52m)
#     Agent 1191 assigned to Lane 194 (distance: 0.67m)
#   Scenario 9d7563e9b6486022: Assigning agents to lanes...
#     Agent 291 assigned to Lane 110 (distance: 0.10m)
#     Agent 292 assigned to Lane 117 (distance: 0.02m)
#     Agent 293 assigned to Lane 97 (distance: 0.31m)
#     Agent 295 assigned to Lane 97 (distance: 0.10m)
#     Agent 297 assigned to Lane 230 (distance: 2.14m)
#     Agent 1056 assigned to Lane 112 (distance: 0.44m)
#   Scenario 3114f7fbaa8cc086: Assigning agents to lanes...
#     Agent 516 assigned to Lane 353 (distance: 0.28m)
#     Agent 517 assigned to Lane 353 (distance: 0.04m)
#     Agent 518 assigned to Lane 355 (distance: 0.07m)
#     Agent 519 assigned to Lane 355 (distance: 0.03m)
#     Agent 520 assigned to Lane 352 (distance: 0.00m)
#     Agent 521 assigned to Lane 355 (distance: 0.16m)
#     Agent 522 assigned to Lane 352 (distance: 0.09m)
#     Agent 523 assigned to Lane 352 (distance: 0.62m)
#     Agent 525 assigned to Lane 352 (distance: 0.83m)
#     Agent 527 assigned to Lane 235 (distance: 0.59m)
#     Agent 528 assigned to Lane 365 (distance: 0.71m)
#     Agent 529 assigned to Lane 355 (distance: 0.16m)
#     Agent 530 assigned to Lane 307 (distance: 0.26m)
#     Agent 531 assigned to Lane 307 (distance: 0.09m)
#     Agent 532 assigned to Lane 355 (distance: 0.03m)
#     Agent 533 assigned to Lane 264 (distance: 0.04m)
#     Agent 534 assigned to Lane 263 (distance: 0.08m)
#     Agent 535 assigned to Lane 352 (distance: 0.23m)
#     Agent 536 assigned to Lane 265 (distance: 0.39m)
#     Agent 537 assigned to Lane 236 (distance: 0.19m)
#     Agent 539 assigned to Lane 352 (distance: 0.40m)
#     Agent 540 assigned to Lane 241 (distance: 0.51m)
#     Agent 541 assigned to Lane 251 (distance: 0.73m)
#     Agent 545 assigned to Lane 352 (distance: 0.21m)
#     Agent 548 assigned to Lane 352 (distance: 0.14m)
#     Agent 550 assigned to Lane 352 (distance: 0.19m)
#     Agent 560 assigned to Lane 297 (distance: 0.99m)
#     Agent 562 assigned to Lane 255 (distance: 0.12m)
#     Agent 563 assigned to Lane 353 (distance: 0.10m)
#     Agent 567 assigned to Lane 263 (distance: 0.13m)
#     Agent 568 assigned to Lane 238 (distance: 1.25m)
#     Agent 5055 assigned to Lane 353 (distance: 0.11m)
#   Scenario 5cac897a524d2f40: Assigning agents to lanes...
#     Agent 3918 assigned to Lane 158 (distance: 0.18m)
#     Agent 1364 assigned to Lane 189 (distance: 0.43m)
#     Agent 1365 assigned to Lane 188 (distance: 0.01m)
#     Agent 1369 assigned to Lane 187 (distance: 0.01m)
#     Agent 1370 assigned to Lane 189 (distance: 0.17m)
#     Agent 1371 assigned to Lane 187 (distance: 0.20m)
#     Agent 1372 assigned to Lane 187 (distance: 0.02m)
#     Agent 1373 assigned to Lane 187 (distance: 0.10m)
#     Agent 1374 assigned to Lane 187 (distance: 0.02m)
#     Agent 1379 assigned to Lane 257 (distance: 0.73m)
#     Agent 1381 assigned to Lane 187 (distance: 0.40m)
#     Agent 1385 assigned to Lane 154 (distance: 0.29m)
#     Agent 1417 assigned to Lane 270 (distance: 0.15m)
#     Agent 1421 assigned to Lane 187 (distance: 0.47m)
#     Agent 1423 assigned to Lane 187 (distance: 1.84m)
#     Agent 1424 assigned to Lane 216 (distance: 1.24m)
#     Agent 1432 assigned to Lane 211 (distance: 0.00m)
#     Agent 1434 assigned to Lane 217 (distance: 0.13m)
#     Agent 1441 assigned to Lane 254 (distance: 0.22m)
#     Agent 1449 assigned to Lane 252 (distance: 0.22m)
#     Agent 3983 assigned to Lane 189 (distance: 0.01m)
#   Scenario 104202f4f2590dff: Assigning agents to lanes...
#     Agent 0 assigned to Lane 220 (distance: 0.32m)
#     Agent 1 assigned to Lane 270 (distance: 0.09m)
#     Agent 3 assigned to Lane 218 (distance: 0.62m)
#     Agent 5 assigned to Lane 238 (distance: 0.38m)
#     Agent 6 assigned to Lane 270 (distance: 0.58m)
#     Agent 7 assigned to Lane 220 (distance: 0.50m)
#     Agent 8 assigned to Lane 185 (distance: 2.11m)
#     Agent 11 assigned to Lane 213 (distance: 0.13m)
#     Agent 12 assigned to Lane 187 (distance: 0.50m)
#     Agent 13 assigned to Lane 216 (distance: 0.02m)
#     Agent 15 assigned to Lane 191 (distance: 0.21m)
#     Agent 16 assigned to Lane 217 (distance: 0.17m)
#     Agent 17 assigned to Lane 212 (distance: 0.77m)
#     Agent 20 assigned to Lane 114 (distance: 0.11m)
#     Agent 21 assigned to Lane 270 (distance: 0.11m)
#     Agent 22 assigned to Lane 184 (distance: 1.59m)
#     Agent 25 assigned to Lane 206 (distance: 0.27m)
#     Agent 28 assigned to Lane 183 (distance: 0.56m)
#     Agent 30 assigned to Lane 114 (distance: 0.34m)
#     Agent 45 assigned to Lane 183 (distance: 1.55m)
#     Agent 51 assigned to Lane 238 (distance: 0.11m)
#     Agent 55 assigned to Lane 269 (distance: 0.08m)
#     Agent 56 assigned to Lane 244 (distance: 0.21m)
#     Agent 61 assigned to Lane 238 (distance: 0.21m)
#     Agent 65 assigned to Lane 238 (distance: 0.18m)
#     Agent 68 assigned to Lane 211 (distance: 0.24m)
#     Agent 69 assigned to Lane 238 (distance: 0.38m)
#     Agent 70 assigned to Lane 191 (distance: 0.35m)
#     Agent 73 assigned to Lane 208 (distance: 1.24m)
#     Agent 74 assigned to Lane 238 (distance: 0.37m)
#     Agent 77 assigned to Lane 244 (distance: 0.95m)
#     Agent 202 assigned to Lane 245 (distance: 0.25m)
#   Scenario f6e89ee29a5f20b2: Assigning agents to lanes...
#     Agent 149 assigned to Lane 107 (distance: 1.44m)
#     Agent 163 assigned to Lane 105 (distance: 0.99m)
#     Agent 187 assigned to Lane 108 (distance: 0.19m)
#   Scenario b6152ff56baf6817: Assigning agents to lanes...
#     Agent 1123 assigned to Lane 288 (distance: 0.69m)
#     Agent 1125 assigned to Lane 235 (distance: 2.30m)
#     Agent 1126 assigned to Lane 235 (distance: 2.18m)
#     Agent 1075 assigned to Lane 253 (distance: 0.34m)
#     Agent 1076 assigned to Lane 235 (distance: 0.66m)
#     Agent 1077 assigned to Lane 235 (distance: 2.29m)
#     Agent 1079 assigned to Lane 291 (distance: 2.47m)
#     Agent 1081 assigned to Lane 253 (distance: 0.84m)
#     Agent 1082 assigned to Lane 291 (distance: 1.07m)
#     Agent 1084 assigned to Lane 253 (distance: 0.53m)
#     Agent 1086 assigned to Lane 240 (distance: 0.42m)
#     Agent 1087 assigned to Lane 235 (distance: 0.49m)
#     Agent 1088 assigned to Lane 241 (distance: 0.54m)
#     Agent 1091 assigned to Lane 241 (distance: 0.40m)
#     Agent 1096 assigned to Lane 242 (distance: 1.67m)
#     Agent 1101 assigned to Lane 253 (distance: 0.17m)
#     Agent 1102 assigned to Lane 246 (distance: 0.17m)
#     Agent 1105 assigned to Lane 244 (distance: 0.34m)
#     Agent 1106 assigned to Lane 254 (distance: 0.17m)
#     Agent 2636 assigned to Lane 237 (distance: 0.92m)
#     Agent 1122 assigned to Lane 305 (distance: 2.31m)
#     Agent 2704 assigned to Lane 291 (distance: 1.50m)
#     Agent 2773 assigned to Lane 241 (distance: 1.04m)
#     Agent 2774 assigned to Lane 291 (distance: 0.28m)
#     Agent 1108 assigned to Lane 291 (distance: 1.02m)
#     Agent 1116 assigned to Lane 222 (distance: 0.55m)
#     Agent 2782 assigned to Lane 248 (distance: 1.86m)
#   Scenario 90cdf8a7cb0e097f: Assigning agents to lanes...
#     Agent 198 assigned to Lane 233 (distance: 0.23m)
#     Agent 199 assigned to Lane 230 (distance: 0.35m)
#     Agent 201 assigned to Lane 231 (distance: 0.30m)
#     Agent 202 assigned to Lane 106 (distance: 0.28m)
#     Agent 203 assigned to Lane 231 (distance: 0.05m)
#     Agent 204 assigned to Lane 230 (distance: 0.16m)
#     Agent 206 assigned to Lane 126 (distance: 0.01m)
#     Agent 207 assigned to Lane 128 (distance: 0.10m)
#     Agent 209 assigned to Lane 127 (distance: 0.36m)
#     Agent 210 assigned to Lane 108 (distance: 2.18m)
#     Agent 211 assigned to Lane 231 (distance: 0.20m)
#     Agent 213 assigned to Lane 108 (distance: 2.10m)
#     Agent 219 assigned to Lane 108 (distance: 1.81m)
#     Agent 220 assigned to Lane 127 (distance: 0.54m)
#     Agent 230 assigned to Lane 127 (distance: 0.54m)
#     Agent 232 assigned to Lane 231 (distance: 0.13m)
#     Agent 236 assigned to Lane 108 (distance: 2.14m)
#     Agent 237 assigned to Lane 101 (distance: 0.65m)
#     Agent 238 assigned to Lane 101 (distance: 0.50m)
#     Agent 243 assigned to Lane 124 (distance: 0.44m)
#     Agent 246 assigned to Lane 129 (distance: 0.05m)
#     Agent 249 assigned to Lane 108 (distance: 2.14m)
#     Agent 251 assigned to Lane 215 (distance: 1.20m)
#     Agent 252 assigned to Lane 128 (distance: 0.35m)
#     Agent 256 assigned to Lane 236 (distance: 0.47m)
#     Agent 1241 assigned to Lane 235 (distance: 0.04m)
#   Scenario 5915f8cd44872858: Assigning agents to lanes...
#     Agent 706 assigned to Lane 200 (distance: 0.09m)
#     Agent 707 assigned to Lane 203 (distance: 0.09m)
#     Agent 709 assigned to Lane 200 (distance: 0.23m)
#     Agent 711 assigned to Lane 302 (distance: 0.26m)
#     Agent 712 assigned to Lane 200 (distance: 0.44m)
#     Agent 714 assigned to Lane 291 (distance: 0.07m)
#     Agent 717 assigned to Lane 305 (distance: 0.10m)
#     Agent 718 assigned to Lane 275 (distance: 0.14m)
#     Agent 727 assigned to Lane 203 (distance: 0.14m)
#     Agent 731 assigned to Lane 255 (distance: 0.07m)
#     Agent 735 assigned to Lane 200 (distance: 0.26m)
#     Agent 741 assigned to Lane 94 (distance: 0.33m)
#     Agent 754 assigned to Lane 198 (distance: 0.53m)
#     Agent 762 assigned to Lane 274 (distance: 0.49m)
#     Agent 773 assigned to Lane 239 (distance: 1.00m)
#     Agent 776 assigned to Lane 123 (distance: 0.33m)
#     Agent 777 assigned to Lane 293 (distance: 0.24m)
#     Agent 781 assigned to Lane 305 (distance: 0.29m)
#     Agent 784 assigned to Lane 292 (distance: 0.16m)
#     Agent 785 assigned to Lane 255 (distance: 0.10m)
#     Agent 789 assigned to Lane 293 (distance: 0.02m)
#     Agent 790 assigned to Lane 316 (distance: 0.22m)
#     Agent 793 assigned to Lane 254 (distance: 0.16m)
#     Agent 795 assigned to Lane 122 (distance: 0.24m)
#     Agent 1116 assigned to Lane 203 (distance: 0.17m)
#   Scenario 8c4eaec3edd72d1b: Assigning agents to lanes...
#     Agent 0 assigned to Lane 131 (distance: 0.11m)
#     Agent 1 assigned to Lane 308 (distance: 0.08m)
#     Agent 2 assigned to Lane 327 (distance: 0.29m)
#     Agent 3 assigned to Lane 329 (distance: 0.12m)
#     Agent 4 assigned to Lane 338 (distance: 0.11m)
#     Agent 7 assigned to Lane 301 (distance: 0.34m)
#     Agent 8 assigned to Lane 338 (distance: 0.01m)
#     Agent 9 assigned to Lane 220 (distance: 0.65m)
#     Agent 10 assigned to Lane 317 (distance: 0.79m)
#     Agent 11 assigned to Lane 289 (distance: 0.22m)
#     Agent 12 assigned to Lane 220 (distance: 0.63m)
#     Agent 56 assigned to Lane 318 (distance: 1.16m)
#     Agent 57 assigned to Lane 131 (distance: 0.01m)
#   Scenario e12f0928016d6956: Assigning agents to lanes...
#     Agent 3 assigned to Lane 95 (distance: 2.38m)
#     Agent 5 assigned to Lane 94 (distance: 1.75m)
#     Agent 6 assigned to Lane 94 (distance: 2.01m)
#     Agent 7 assigned to Lane 95 (distance: 2.35m)
#     Agent 10 assigned to Lane 106 (distance: 1.92m)
#     Agent 11 assigned to Lane 93 (distance: 2.08m)
#     Agent 12 assigned to Lane 95 (distance: 2.41m)
#     Agent 14 assigned to Lane 106 (distance: 1.76m)
#     Agent 17 assigned to Lane 106 (distance: 2.13m)
#     Agent 18 assigned to Lane 106 (distance: 1.88m)
#     Agent 21 assigned to Lane 136 (distance: 1.99m)
#     Agent 24 assigned to Lane 94 (distance: 0.58m)
#     Agent 25 assigned to Lane 112 (distance: 2.25m)
#     Agent 28 assigned to Lane 93 (distance: 2.40m)
#     Agent 30 assigned to Lane 136 (distance: 2.27m)
#     Agent 47 assigned to Lane 112 (distance: 2.30m)
#     Agent 48 assigned to Lane 106 (distance: 1.87m)
#     Agent 49 assigned to Lane 112 (distance: 2.31m)
#     Agent 50 assigned to Lane 112 (distance: 2.29m)
#     Agent 55 assigned to Lane 102 (distance: 2.41m)
#     Agent 56 assigned to Lane 102 (distance: 2.38m)
#     Agent 57 assigned to Lane 102 (distance: 2.11m)
#     Agent 58 assigned to Lane 95 (distance: 2.00m)
#     Agent 59 assigned to Lane 102 (distance: 2.26m)
#     Agent 101 assigned to Lane 100 (distance: 0.15m)
#     Agent 102 assigned to Lane 106 (distance: 2.48m)
#     Agent 162 assigned to Lane 94 (distance: 0.27m)
#     Agent 163 assigned to Lane 94 (distance: 0.13m)
#     Agent 164 assigned to Lane 101 (distance: 0.75m)
#   Scenario 79776dd1931a3d26: Assigning agents to lanes...
#     Agent 2 assigned to Lane 263 (distance: 0.87m)
#     Agent 5 assigned to Lane 255 (distance: 0.37m)
#     Agent 14 assigned to Lane 258 (distance: 0.19m)
#     Agent 23 assigned to Lane 341 (distance: 2.34m)
#     Agent 26 assigned to Lane 258 (distance: 0.28m)
#     Agent 27 assigned to Lane 258 (distance: 0.17m)
#     Agent 38 assigned to Lane 258 (distance: 0.16m)
#     Agent 44 assigned to Lane 258 (distance: 0.21m)
#     Agent 48 assigned to Lane 258 (distance: 0.05m)
#     Agent 54 assigned to Lane 258 (distance: 0.05m)
#     Agent 66 assigned to Lane 342 (distance: 0.53m)
#     Agent 70 assigned to Lane 281 (distance: 1.97m)
#     Agent 75 assigned to Lane 281 (distance: 2.33m)
#     Agent 291 assigned to Lane 324 (distance: 0.05m)
#     Agent 294 assigned to Lane 255 (distance: 0.01m)
#   Scenario c692808f8d63a7ec: Assigning agents to lanes...
#     Agent 108 assigned to Lane 491 (distance: 0.36m)
#     Agent 110 assigned to Lane 492 (distance: 0.20m)
#     Agent 113 assigned to Lane 431 (distance: 0.09m)
#     Agent 117 assigned to Lane 431 (distance: 0.18m)
#     Agent 118 assigned to Lane 160 (distance: 0.00m)
#     Agent 119 assigned to Lane 491 (distance: 0.14m)
#     Agent 120 assigned to Lane 492 (distance: 0.07m)
#     Agent 126 assigned to Lane 313 (distance: 0.06m)
#     Agent 129 assigned to Lane 492 (distance: 0.03m)
#     Agent 130 assigned to Lane 160 (distance: 0.69m)
#     Agent 134 assigned to Lane 424 (distance: 0.08m)
#     Agent 143 assigned to Lane 425 (distance: 0.34m)
#     Agent 146 assigned to Lane 158 (distance: 1.35m)
#     Agent 151 assigned to Lane 490 (distance: 0.20m)
#     Agent 152 assigned to Lane 490 (distance: 0.27m)
#     Agent 154 assigned to Lane 326 (distance: 0.31m)
#     Agent 164 assigned to Lane 211 (distance: 0.12m)
#     Agent 166 assigned to Lane 209 (distance: 0.37m)
#     Agent 175 assigned to Lane 491 (distance: 0.12m)
#     Agent 177 assigned to Lane 211 (distance: 0.36m)
#     Agent 409 assigned to Lane 491 (distance: 0.07m)
#   Scenario c354985f8a63a390: Assigning agents to lanes...
#     Agent 846 assigned to Lane 308 (distance: 0.53m)
#     Agent 847 assigned to Lane 328 (distance: 1.98m)
#     Agent 851 assigned to Lane 701 (distance: 0.07m)
#     Agent 853 assigned to Lane 246 (distance: 0.42m)
#     Agent 858 assigned to Lane 245 (distance: 0.27m)
#     Agent 862 assigned to Lane 244 (distance: 0.02m)
#     Agent 864 assigned to Lane 314 (distance: 0.49m)
#     Agent 865 assigned to Lane 243 (distance: 0.12m)
#     Agent 866 assigned to Lane 242 (distance: 0.23m)
#     Agent 867 assigned to Lane 697 (distance: 0.05m)
#     Agent 870 assigned to Lane 748 (distance: 0.03m)
#     Agent 1061 assigned to Lane 338 (distance: 0.00m)
#   Scenario d8036e6d7e2a86a2: Assigning agents to lanes...
#     Agent 1151 assigned to Lane 156 (distance: 0.27m)
#     Agent 182 assigned to Lane 144 (distance: 0.59m)
#     Agent 183 assigned to Lane 144 (distance: 2.34m)
#     Agent 184 assigned to Lane 144 (distance: 1.35m)
#     Agent 185 assigned to Lane 155 (distance: 1.24m)
#     Agent 187 assigned to Lane 145 (distance: 2.25m)
#     Agent 188 assigned to Lane 75 (distance: 1.60m)
#     Agent 189 assigned to Lane 145 (distance: 2.35m)
#     Agent 192 assigned to Lane 75 (distance: 2.34m)
#     Agent 194 assigned to Lane 141 (distance: 2.47m)
#     Agent 195 assigned to Lane 145 (distance: 2.20m)
#     Agent 196 assigned to Lane 146 (distance: 2.34m)
#     Agent 198 assigned to Lane 154 (distance: 2.43m)
#     Agent 203 assigned to Lane 141 (distance: 2.42m)
#     Agent 208 assigned to Lane 142 (distance: 2.37m)
#     Agent 213 assigned to Lane 75 (distance: 2.37m)
#     Agent 218 assigned to Lane 154 (distance: 2.23m)
#     Agent 225 assigned to Lane 141 (distance: 0.81m)
#     Agent 228 assigned to Lane 141 (distance: 2.44m)
#     Agent 229 assigned to Lane 75 (distance: 1.26m)
#     Agent 231 assigned to Lane 154 (distance: 2.36m)
#     Agent 1152 assigned to Lane 144 (distance: 0.39m)
#   Scenario 11e688db089d222: Assigning agents to lanes...
#     Agent 515 assigned to Lane 351 (distance: 0.29m)
#     Agent 520 assigned to Lane 358 (distance: 0.53m)
#     Agent 486 assigned to Lane 329 (distance: 0.42m)
#     Agent 488 assigned to Lane 331 (distance: 0.01m)
#     Agent 1877 assigned to Lane 331 (distance: 0.07m)
#   Scenario 197433a84d86f4b6: Assigning agents to lanes...
#     Agent 1179 assigned to Lane 208 (distance: 0.48m)
#     Agent 1207 assigned to Lane 260 (distance: 0.44m)
#     Agent 1210 assigned to Lane 261 (distance: 1.39m)
#     Agent 1223 assigned to Lane 310 (distance: 0.31m)
#     Agent 1250 assigned to Lane 308 (distance: 0.20m)
#     Agent 1559 assigned to Lane 264 (distance: 0.69m)
#   Scenario 2364a51095c69102: Assigning agents to lanes...
#     Agent 2048 assigned to Lane 217 (distance: 0.07m)
#     Agent 2051 assigned to Lane 261 (distance: 0.51m)
#     Agent 2053 assigned to Lane 219 (distance: 0.19m)
#     Agent 2055 assigned to Lane 246 (distance: 0.65m)
#     Agent 2056 assigned to Lane 316 (distance: 0.19m)
#     Agent 2060 assigned to Lane 148 (distance: 0.01m)
#     Agent 2065 assigned to Lane 242 (distance: 0.15m)
#     Agent 2067 assigned to Lane 218 (distance: 0.65m)
#     Agent 2069 assigned to Lane 216 (distance: 0.37m)
#     Agent 2070 assigned to Lane 261 (distance: 0.36m)
#     Agent 2080 assigned to Lane 148 (distance: 0.22m)
#     Agent 2081 assigned to Lane 268 (distance: 0.32m)
#     Agent 2082 assigned to Lane 273 (distance: 0.75m)
#     Agent 2412 assigned to Lane 248 (distance: 0.61m)
#     Agent 1991 assigned to Lane 401 (distance: 0.04m)
#     Agent 1992 assigned to Lane 231 (distance: 0.25m)
#     Agent 1994 assigned to Lane 401 (distance: 0.04m)
#     Agent 1995 assigned to Lane 400 (distance: 0.17m)
#     Agent 1996 assigned to Lane 403 (distance: 0.09m)
#     Agent 1998 assigned to Lane 273 (distance: 0.34m)
#     Agent 1999 assigned to Lane 400 (distance: 0.33m)
#     Agent 2001 assigned to Lane 268 (distance: 0.09m)
#     Agent 2002 assigned to Lane 268 (distance: 0.01m)
#     Agent 2004 assigned to Lane 267 (distance: 0.38m)
#     Agent 2006 assigned to Lane 410 (distance: 0.03m)
#     Agent 2007 assigned to Lane 403 (distance: 0.05m)
#     Agent 2009 assigned to Lane 404 (distance: 0.19m)
#     Agent 2011 assigned to Lane 273 (distance: 0.64m)
#     Agent 2012 assigned to Lane 267 (distance: 0.08m)
#     Agent 2014 assigned to Lane 403 (distance: 0.05m)
#     Agent 2015 assigned to Lane 409 (distance: 0.76m)
#     Agent 2016 assigned to Lane 234 (distance: 0.56m)
#     Agent 2020 assigned to Lane 268 (distance: 0.00m)
#     Agent 2021 assigned to Lane 409 (distance: 0.20m)
#     Agent 2022 assigned to Lane 243 (distance: 0.17m)
#     Agent 2023 assigned to Lane 267 (distance: 0.04m)
#     Agent 2024 assigned to Lane 240 (distance: 0.25m)
#     Agent 2030 assigned to Lane 401 (distance: 0.52m)
#     Agent 2031 assigned to Lane 249 (distance: 0.01m)
#     Agent 2036 assigned to Lane 268 (distance: 0.16m)
#     Agent 2043 assigned to Lane 260 (distance: 0.66m)
#     Agent 2045 assigned to Lane 254 (distance: 0.20m)
#     Agent 2047 assigned to Lane 241 (distance: 0.31m)
#     Agent 3848 assigned to Lane 403 (distance: 0.18m)
#   Scenario bffa6dd429936879: Assigning agents to lanes...
#     Agent 2 assigned to Lane 697 (distance: 0.08m)
#     Agent 3 assigned to Lane 708 (distance: 0.24m)
#     Agent 6 assigned to Lane 703 (distance: 0.90m)
#     Agent 11 assigned to Lane 443 (distance: 0.04m)
#     Agent 12 assigned to Lane 443 (distance: 0.18m)
#     Agent 66 assigned to Lane 697 (distance: 0.97m)
#     Agent 75 assigned to Lane 770 (distance: 0.58m)
#     Agent 90 assigned to Lane 712 (distance: 0.47m)
#     Agent 141 assigned to Lane 574 (distance: 0.29m)
#     Agent 211 assigned to Lane 443 (distance: 0.00m)
#   Scenario 4a116dacc9ccc4df: Assigning agents to lanes...
#     Agent 208 assigned to Lane 41 (distance: 2.43m)
#     Agent 209 assigned to Lane 63 (distance: 1.11m)
#     Agent 213 assigned to Lane 41 (distance: 2.46m)
#     Agent 217 assigned to Lane 41 (distance: 2.42m)
#     Agent 218 assigned to Lane 62 (distance: 2.00m)
#     Agent 220 assigned to Lane 41 (distance: 2.35m)
#     Agent 221 assigned to Lane 62 (distance: 2.05m)
#     Agent 1052 assigned to Lane 66 (distance: 0.63m)
#   Scenario 3ec9f6dfb2b48d65: Assigning agents to lanes...
#     Agent 1432 assigned to Lane 380 (distance: 0.04m)
#     Agent 858 assigned to Lane 374 (distance: 0.93m)
#     Agent 879 assigned to Lane 378 (distance: 0.45m)
#     Agent 884 assigned to Lane 379 (distance: 0.32m)
#     Agent 886 assigned to Lane 382 (distance: 2.26m)
#     Agent 888 assigned to Lane 195 (distance: 0.12m)
#     Agent 890 assigned to Lane 195 (distance: 0.31m)
#     Agent 894 assigned to Lane 197 (distance: 0.24m)
#     Agent 895 assigned to Lane 379 (distance: 0.01m)
#     Agent 897 assigned to Lane 197 (distance: 0.05m)
#     Agent 898 assigned to Lane 196 (distance: 0.20m)
#     Agent 900 assigned to Lane 316 (distance: 0.37m)
#     Agent 902 assigned to Lane 379 (distance: 0.63m)
#     Agent 904 assigned to Lane 340 (distance: 1.28m)
#     Agent 907 assigned to Lane 196 (distance: 0.19m)
#     Agent 909 assigned to Lane 195 (distance: 0.04m)
#     Agent 910 assigned to Lane 325 (distance: 0.23m)
#     Agent 911 assigned to Lane 324 (distance: 0.31m)
#     Agent 914 assigned to Lane 196 (distance: 0.03m)
#     Agent 912 assigned to Lane 323 (distance: 0.09m)
#     Agent 916 assigned to Lane 316 (distance: 0.40m)
#     Agent 917 assigned to Lane 324 (distance: 0.33m)
#     Agent 923 assigned to Lane 195 (distance: 0.31m)
#     Agent 922 assigned to Lane 196 (distance: 0.05m)
#     Agent 924 assigned to Lane 358 (distance: 0.22m)
#     Agent 926 assigned to Lane 381 (distance: 0.05m)
#     Agent 928 assigned to Lane 196 (distance: 0.24m)
#     Agent 929 assigned to Lane 430 (distance: 2.25m)
#     Agent 930 assigned to Lane 195 (distance: 0.25m)
#     Agent 931 assigned to Lane 197 (distance: 0.05m)
#     Agent 933 assigned to Lane 324 (distance: 0.36m)
#     Agent 934 assigned to Lane 157 (distance: 0.03m)
#     Agent 936 assigned to Lane 195 (distance: 0.29m)
#     Agent 1450 assigned to Lane 380 (distance: 0.08m)
#     Agent 941 assigned to Lane 196 (distance: 0.10m)
#     Agent 942 assigned to Lane 316 (distance: 1.00m)
#     Agent 1454 assigned to Lane 163 (distance: 0.09m)
#   Scenario ab06fe2bdd70dee8: Assigning agents to lanes...
#     Agent 1152 assigned to Lane 259 (distance: 0.25m)
#     Agent 1153 assigned to Lane 188 (distance: 0.72m)
#     Agent 1164 assigned to Lane 196 (distance: 0.26m)
#     Agent 1143 assigned to Lane 217 (distance: 0.05m)
#     Agent 1144 assigned to Lane 219 (distance: 0.28m)
#     Agent 1146 assigned to Lane 184 (distance: 0.04m)
#     Agent 1148 assigned to Lane 219 (distance: 0.49m)
#     Agent 1149 assigned to Lane 187 (distance: 0.05m)
#     Agent 1150 assigned to Lane 183 (distance: 0.06m)
#     Agent 1200 assigned to Lane 218 (distance: 0.21m)
#   Scenario beeee363eeb3f708: Assigning agents to lanes...
#     Agent 611 assigned to Lane 485 (distance: 0.30m)
#     Agent 613 assigned to Lane 489 (distance: 0.15m)
#     Agent 614 assigned to Lane 559 (distance: 1.82m)
#     Agent 615 assigned to Lane 553 (distance: 0.29m)
#     Agent 618 assigned to Lane 557 (distance: 0.23m)
#     Agent 619 assigned to Lane 571 (distance: 0.07m)
#     Agent 623 assigned to Lane 484 (distance: 1.96m)
#     Agent 628 assigned to Lane 571 (distance: 0.33m)
#     Agent 631 assigned to Lane 299 (distance: 1.01m)
#     Agent 640 assigned to Lane 485 (distance: 0.02m)
#     Agent 648 assigned to Lane 557 (distance: 0.05m)
#     Agent 649 assigned to Lane 571 (distance: 0.16m)
#     Agent 653 assigned to Lane 489 (distance: 0.37m)
#     Agent 655 assigned to Lane 488 (distance: 0.20m)
#     Agent 657 assigned to Lane 492 (distance: 0.19m)
#     Agent 659 assigned to Lane 485 (distance: 0.06m)
#     Agent 660 assigned to Lane 554 (distance: 0.14m)
#     Agent 661 assigned to Lane 489 (distance: 0.47m)
#     Agent 662 assigned to Lane 488 (distance: 0.20m)
#     Agent 667 assigned to Lane 492 (distance: 1.21m)
#     Agent 669 assigned to Lane 557 (distance: 0.02m)
#     Agent 670 assigned to Lane 489 (distance: 0.61m)
#     Agent 671 assigned to Lane 554 (distance: 0.26m)
#     Agent 672 assigned to Lane 485 (distance: 0.12m)
#     Agent 673 assigned to Lane 488 (distance: 0.02m)
#     Agent 675 assigned to Lane 494 (distance: 0.03m)
#     Agent 676 assigned to Lane 492 (distance: 0.46m)
#     Agent 677 assigned to Lane 485 (distance: 0.09m)
#     Agent 678 assigned to Lane 493 (distance: 0.02m)
#     Agent 679 assigned to Lane 554 (distance: 0.15m)
#     Agent 680 assigned to Lane 557 (distance: 0.03m)
#     Agent 681 assigned to Lane 494 (distance: 0.03m)
#     Agent 686 assigned to Lane 493 (distance: 0.07m)
#     Agent 688 assigned to Lane 554 (distance: 0.17m)
#     Agent 689 assigned to Lane 245 (distance: 0.21m)
#     Agent 690 assigned to Lane 494 (distance: 0.35m)
#     Agent 691 assigned to Lane 431 (distance: 0.02m)
#     Agent 692 assigned to Lane 494 (distance: 0.02m)
#     Agent 693 assigned to Lane 557 (distance: 0.24m)
#     Agent 734 assigned to Lane 557 (distance: 0.03m)
#   Scenario f84a2c81fec0b16: Assigning agents to lanes...
#     Agent 1065 assigned to Lane 387 (distance: 0.19m)
#     Agent 1066 assigned to Lane 244 (distance: 0.59m)
#     Agent 1070 assigned to Lane 144 (distance: 0.06m)
#     Agent 1076 assigned to Lane 358 (distance: 0.73m)
# ...
#     Agent 2784 assigned to Lane 215 (distance: 0.46m)
#     Agent 6511 assigned to Lane 185 (distance: 0.81m)
#     Agent 759 assigned to Lane 215 (distance: 1.84m)
#     Agent 761 assigned to Lane 215 (distance: 1.53m)
#     Agent 762 assigned to Lane 215 (distance: 1.79m)
#     Agent 763 assigned to Lane 215 (distance: 1.49m)
#     Agent 764 assigned to Lane 215 (distance: 2.11m)
#     Agent 766 assigned to Lane 306 (distance: 1.87m)
#     Agent 6512 assigned to Lane 215 (distance: 0.75m)
#   Scenario 21f584ad2dd5d7b8: Assigning agents to lanes...
#     Agent 2 assigned to Lane 337 (distance: 1.35m)
#     Agent 11 assigned to Lane 260 (distance: 0.08m)
#     Agent 14 assigned to Lane 201 (distance: 1.74m)
#     Agent 23 assigned to Lane 260 (distance: 0.21m)
#     Agent 25 assigned to Lane 261 (distance: 0.25m)
#     Agent 47 assigned to Lane 260 (distance: 0.11m)
#     Agent 53 assigned to Lane 260 (distance: 0.27m)
#     Agent 59 assigned to Lane 259 (distance: 0.08m)
#     Agent 79 assigned to Lane 207 (distance: 0.40m)
#     Agent 177 assigned to Lane 255 (distance: 0.02m)
#   Scenario 852bf8201e701c22: Assigning agents to lanes...
#     Agent 0 assigned to Lane 128 (distance: 0.18m)
#     Agent 1 assigned to Lane 128 (distance: 0.25m)
#     Agent 2 assigned to Lane 139 (distance: 0.47m)
#     Agent 3 assigned to Lane 133 (distance: 0.21m)
#     Agent 4 assigned to Lane 173 (distance: 2.14m)
#     Agent 5 assigned to Lane 128 (distance: 0.06m)
#     Agent 6 assigned to Lane 125 (distance: 0.31m)
#     Agent 8 assigned to Lane 175 (distance: 0.41m)
#     Agent 9 assigned to Lane 127 (distance: 0.11m)
#     Agent 10 assigned to Lane 125 (distance: 0.03m)
#     Agent 11 assigned to Lane 175 (distance: 0.19m)
#     Agent 66 assigned to Lane 125 (distance: 0.30m)
#   Scenario c93b188ee1c507d5: Assigning agents to lanes...
#     Agent 1597 assigned to Lane 398 (distance: 0.07m)
#     Agent 1637 assigned to Lane 423 (distance: 0.07m)
#     Agent 1668 assigned to Lane 542 (distance: 0.71m)
#     Agent 1856 assigned to Lane 538 (distance: 0.59m)
#     Agent 1472 assigned to Lane 536 (distance: 1.42m)
#     Agent 1486 assigned to Lane 612 (distance: 0.50m)
#     Agent 1894 assigned to Lane 533 (distance: 0.42m)
#   Scenario 5510d6a966ccc52f: Assigning agents to lanes...
#     Agent 624 assigned to Lane 355 (distance: 0.08m)
#     Agent 626 assigned to Lane 355 (distance: 0.18m)
#     Agent 629 assigned to Lane 229 (distance: 0.21m)
#     Agent 631 assigned to Lane 359 (distance: 0.12m)
#     Agent 644 assigned to Lane 229 (distance: 0.30m)
#     Agent 661 assigned to Lane 355 (distance: 0.17m)
#     Agent 664 assigned to Lane 360 (distance: 0.01m)
#     Agent 671 assigned to Lane 229 (distance: 0.21m)
#     Agent 672 assigned to Lane 360 (distance: 0.17m)
#     Agent 683 assigned to Lane 158 (distance: 0.06m)
#     Agent 686 assigned to Lane 356 (distance: 0.08m)
#     Agent 687 assigned to Lane 193 (distance: 0.50m)
#     Agent 696 assigned to Lane 355 (distance: 0.19m)
#     Agent 731 assigned to Lane 355 (distance: 0.07m)
#   Scenario 430a2693b92ba127: Assigning agents to lanes...
#     Agent 1418 assigned to Lane 411 (distance: 1.03m)
#     Agent 1430 assigned to Lane 406 (distance: 0.17m)
#     Agent 1431 assigned to Lane 608 (distance: 0.12m)
#     Agent 1433 assigned to Lane 612 (distance: 0.02m)
#     Agent 1438 assigned to Lane 619 (distance: 0.20m)
#     Agent 1444 assigned to Lane 416 (distance: 0.03m)
#     Agent 1457 assigned to Lane 194 (distance: 0.08m)
#     Agent 1636 assigned to Lane 407 (distance: 1.10m)
#   Scenario 715dfdaa4cf40df5: Assigning agents to lanes...
#     Agent 1796 assigned to Lane 272 (distance: 0.01m)
#     Agent 1778 assigned to Lane 336 (distance: 1.29m)
#     Agent 1780 assigned to Lane 319 (distance: 0.08m)
#     Agent 1782 assigned to Lane 318 (distance: 1.17m)
#     Agent 1784 assigned to Lane 322 (distance: 0.35m)
#     Agent 2422 assigned to Lane 330 (distance: 0.29m)
#   Scenario 3946229358696c01: Assigning agents to lanes...
#     Agent 837 assigned to Lane 102 (distance: 0.80m)
#     Agent 849 assigned to Lane 71 (distance: 0.02m)
#     Agent 857 assigned to Lane 149 (distance: 0.10m)
#     Agent 858 assigned to Lane 79 (distance: 0.19m)
#   Scenario 32f0ee473bcb2854: Assigning agents to lanes...
#     Agent 530 assigned to Lane 794 (distance: 0.41m)
#     Agent 531 assigned to Lane 787 (distance: 0.18m)
#     Agent 532 assigned to Lane 806 (distance: 0.12m)
#     Agent 533 assigned to Lane 431 (distance: 0.18m)
#     Agent 534 assigned to Lane 787 (distance: 0.72m)
#     Agent 537 assigned to Lane 425 (distance: 0.58m)
#     Agent 549 assigned to Lane 787 (distance: 0.45m)
#     Agent 561 assigned to Lane 794 (distance: 0.04m)
#     Agent 564 assigned to Lane 791 (distance: 0.33m)
#     Agent 570 assigned to Lane 803 (distance: 1.09m)
#     Agent 579 assigned to Lane 431 (distance: 0.30m)
#     Agent 583 assigned to Lane 741 (distance: 0.24m)
#     Agent 586 assigned to Lane 438 (distance: 0.22m)
#     Agent 587 assigned to Lane 435 (distance: 0.27m)
#     Agent 590 assigned to Lane 435 (distance: 0.25m)
#     Agent 591 assigned to Lane 438 (distance: 0.03m)
#     Agent 593 assigned to Lane 788 (distance: 0.44m)
#     Agent 594 assigned to Lane 433 (distance: 0.04m)
#     Agent 597 assigned to Lane 725 (distance: 0.62m)
#     Agent 649 assigned to Lane 431 (distance: 0.32m)
#   Scenario 27e52c5f34743a32: Assigning agents to lanes...
#     Agent 487 assigned to Lane 118 (distance: 0.05m)
#     Agent 701 assigned to Lane 112 (distance: 1.31m)
# /tmp/ipykernel_8625/1875686489.py:97: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   fig.canvas.draw()
#   Scenario 4bf1d627f1771287: Assigning agents to lanes...
#     Agent 0 assigned to Lane 135 (distance: 0.14m)
#     Agent 1 assigned to Lane 155 (distance: 0.04m)
#     Agent 2 assigned to Lane 155 (distance: 0.17m)
#     Agent 3 assigned to Lane 172 (distance: 0.05m)
#     Agent 4 assigned to Lane 179 (distance: 0.33m)
#     Agent 5 assigned to Lane 140 (distance: 0.12m)
#     Agent 6 assigned to Lane 132 (distance: 0.29m)
#     Agent 7 assigned to Lane 155 (distance: 0.29m)
#     Agent 10 assigned to Lane 167 (distance: 0.68m)
#     Agent 11 assigned to Lane 135 (distance: 0.25m)
#     Agent 12 assigned to Lane 200 (distance: 0.13m)
#     Agent 13 assigned to Lane 146 (distance: 0.11m)
#     Agent 16 assigned to Lane 201 (distance: 0.07m)
#     Agent 18 assigned to Lane 146 (distance: 0.15m)
#     Agent 23 assigned to Lane 155 (distance: 0.20m)
#     Agent 31 assigned to Lane 149 (distance: 0.09m)
#     Agent 34 assigned to Lane 201 (distance: 0.19m)
#     Agent 36 assigned to Lane 150 (distance: 0.66m)
#     Agent 42 assigned to Lane 201 (distance: 0.35m)
#     Agent 43 assigned to Lane 149 (distance: 0.05m)
#     Agent 44 assigned to Lane 201 (distance: 0.30m)
#     Agent 46 assigned to Lane 185 (distance: 0.14m)
#     Agent 47 assigned to Lane 133 (distance: 0.51m)
#     Agent 48 assigned to Lane 200 (distance: 0.18m)
#     Agent 49 assigned to Lane 200 (distance: 0.32m)
#     Agent 54 assigned to Lane 159 (distance: 0.58m)
#     Agent 58 assigned to Lane 200 (distance: 0.09m)
#     Agent 60 assigned to Lane 184 (distance: 0.21m)
#     Agent 61 assigned to Lane 153 (distance: 0.20m)
#     Agent 99 assigned to Lane 162 (distance: 0.06m)
#   Scenario 8a720808ec3c0864: Assigning agents to lanes...
#     Agent 1452 assigned to Lane 634 (distance: 2.44m)
#     Agent 2193 assigned to Lane 632 (distance: 0.83m)
#   Scenario 671dec7d5e2fa9fb: Assigning agents to lanes...
#     Agent 2612 assigned to Lane 163 (distance: 0.75m)
#     Agent 1788 assigned to Lane 237 (distance: 0.15m)
#     Agent 1789 assigned to Lane 212 (distance: 0.20m)
#     Agent 1793 assigned to Lane 240 (distance: 0.18m)
#     Agent 1796 assigned to Lane 168 (distance: 0.20m)
#     Agent 1797 assigned to Lane 218 (distance: 2.44m)
#     Agent 1800 assigned to Lane 255 (distance: 0.71m)
#     Agent 1802 assigned to Lane 218 (distance: 2.37m)
#     Agent 1805 assigned to Lane 218 (distance: 2.44m)
#     Agent 1812 assigned to Lane 255 (distance: 2.42m)
#     Agent 1817 assigned to Lane 237 (distance: 1.09m)
#     Agent 1825 assigned to Lane 204 (distance: 0.11m)
#     Agent 1827 assigned to Lane 218 (distance: 0.17m)
#     Agent 1828 assigned to Lane 206 (distance: 0.10m)
#     Agent 1833 assigned to Lane 266 (distance: 0.43m)
#     Agent 1834 assigned to Lane 204 (distance: 0.24m)
#     Agent 1835 assigned to Lane 266 (distance: 0.21m)
#     Agent 1836 assigned to Lane 257 (distance: 0.25m)
#     Agent 1838 assigned to Lane 257 (distance: 0.60m)
#     Agent 1839 assigned to Lane 258 (distance: 0.45m)
#     Agent 2464 assigned to Lane 224 (distance: 0.63m)
#     Agent 2467 assigned to Lane 218 (distance: 1.14m)
#     Agent 2470 assigned to Lane 251 (distance: 2.20m)
#     Agent 2622 assigned to Lane 237 (distance: 0.04m)
# Exception ignored in: <function WeakValueDictionary.__init__.<locals>.remove at 0x7f2330ed7250>
# Traceback (most recent call last):
#   File "/home/hamdarlab/anaconda3/envs/waymo-env/lib/python3.10/weakref.py", line 106, in remove
#     def remove(wr, selfref=ref(self), _atomic_removal=_remove_dead_weakref):
# KeyboardInterrupt:
#   Scenario 44dc56e65fc65a82: Assigning agents to lanes...
#     Agent 650 assigned to Lane 412 (distance: 0.43m)
#     Agent 655 assigned to Lane 444 (distance: 0.29m)
#     Agent 671 assigned to Lane 384 (distance: 0.29m)
#     Agent 672 assigned to Lane 437 (distance: 0.07m)
#     Agent 675 assigned to Lane 435 (distance: 0.11m)
#     Agent 677 assigned to Lane 424 (distance: 0.08m)
#     Agent 680 assigned to Lane 435 (distance: 0.29m)
#     Agent 688 assigned to Lane 386 (distance: 0.30m)
#     Agent 695 assigned to Lane 425 (distance: 0.02m)
#     Agent 880 assigned to Lane 407 (distance: 0.21m)
#   Scenario 7ac22c9e42d05c79: Assigning agents to lanes...
#     Agent 0 assigned to Lane 155 (distance: 0.16m)
#     Agent 1 assigned to Lane 153 (distance: 0.09m)
#     Agent 2 assigned to Lane 164 (distance: 0.16m)
#     Agent 3 assigned to Lane 166 (distance: 0.95m)
#     Agent 4 assigned to Lane 169 (distance: 0.02m)
#     Agent 5 assigned to Lane 168 (distance: 0.42m)
#     Agent 6 assigned to Lane 153 (distance: 0.05m)
#     Agent 7 assigned to Lane 153 (distance: 0.61m)
#     Agent 8 assigned to Lane 153 (distance: 0.30m)
#     Agent 9 assigned to Lane 112 (distance: 0.05m)
#     Agent 10 assigned to Lane 171 (distance: 0.97m)
#     Agent 12 assigned to Lane 155 (distance: 0.02m)
#     Agent 13 assigned to Lane 225 (distance: 0.01m)
#     Agent 15 assigned to Lane 231 (distance: 1.51m)
#     Agent 20 assigned to Lane 179 (distance: 1.81m)
#     Agent 24 assigned to Lane 232 (distance: 0.25m)
#     Agent 27 assigned to Lane 222 (distance: 0.09m)
#     Agent 28 assigned to Lane 221 (distance: 0.46m)
#     Agent 83 assigned to Lane 165 (distance: 0.03m)
#   Scenario d5327587f925c58e: Assigning agents to lanes...
#     Agent 836 assigned to Lane 245 (distance: 0.31m)
#     Agent 837 assigned to Lane 193 (distance: 0.09m)
#     Agent 839 assigned to Lane 212 (distance: 0.22m)
#     Agent 840 assigned to Lane 245 (distance: 0.05m)
#     Agent 842 assigned to Lane 246 (distance: 0.02m)
#     Agent 843 assigned to Lane 687 (distance: 0.93m)
#     Agent 844 assigned to Lane 214 (distance: 0.20m)
#     Agent 845 assigned to Lane 390 (distance: 0.03m)
#     Agent 846 assigned to Lane 245 (distance: 0.12m)
#     Agent 847 assigned to Lane 214 (distance: 0.50m)
#     Agent 848 assigned to Lane 368 (distance: 0.17m)
#     Agent 849 assigned to Lane 389 (distance: 0.03m)
#     Agent 850 assigned to Lane 392 (distance: 0.32m)
#     Agent 852 assigned to Lane 246 (distance: 0.15m)
#     Agent 855 assigned to Lane 193 (distance: 0.18m)
#     Agent 856 assigned to Lane 687 (distance: 1.09m)
#     Agent 857 assigned to Lane 368 (distance: 0.05m)
#     Agent 858 assigned to Lane 214 (distance: 0.07m)
#     Agent 860 assigned to Lane 390 (distance: 0.06m)
#     Agent 862 assigned to Lane 389 (distance: 0.26m)
#     Agent 866 assigned to Lane 219 (distance: 0.07m)
#     Agent 873 assigned to Lane 219 (distance: 0.57m)
#     Agent 874 assigned to Lane 368 (distance: 0.04m)
#     Agent 877 assigned to Lane 398 (distance: 0.04m)
#     Agent 878 assigned to Lane 259 (distance: 0.11m)
#     Agent 881 assigned to Lane 212 (distance: 0.33m)
#     Agent 885 assigned to Lane 259 (distance: 0.66m)
#     Agent 886 assigned to Lane 259 (distance: 0.54m)
#     Agent 887 assigned to Lane 691 (distance: 0.18m)
#     Agent 1920 assigned to Lane 246 (distance: 0.06m)
#   Scenario a7a3a82d61f0e91e: Assigning agents to lanes...
#     Agent 1229 assigned to Lane 227 (distance: 0.17m)
#     Agent 1233 assigned to Lane 177 (distance: 0.40m)
#     Agent 1239 assigned to Lane 219 (distance: 0.08m)
#     Agent 1240 assigned to Lane 219 (distance: 0.35m)
#     Agent 1241 assigned to Lane 219 (distance: 0.51m)
#     Agent 1304 assigned to Lane 229 (distance: 0.03m)
#   - Successfully plotted 75 out of 75 scenarios from 'training_20s.tfrecord-00000-of-01000'.
#
# [2/20] Processing 'training_20s.tfrecord-00001-of-01000'...
#   Scenario 24280b6e69ccdd04: Assigning agents to lanes...
#     Agent 1024 assigned to Lane 254 (distance: 0.06m)
#     Agent 1025 assigned to Lane 340 (distance: 0.20m)
#     Agent 1028 assigned to Lane 342 (distance: 0.30m)
#     Agent 1031 assigned to Lane 243 (distance: 0.41m)
#     Agent 1032 assigned to Lane 167 (distance: 0.21m)
#     Agent 1034 assigned to Lane 248 (distance: 0.58m)
#     Agent 1035 assigned to Lane 166 (distance: 0.05m)
#     Agent 1036 assigned to Lane 388 (distance: 0.47m)
#     Agent 1037 assigned to Lane 165 (distance: 0.28m)
#     Agent 1038 assigned to Lane 236 (distance: 0.66m)
#     Agent 1039 assigned to Lane 340 (distance: 0.20m)
#     Agent 1040 assigned to Lane 388 (distance: 0.49m)
#     Agent 1041 assigned to Lane 167 (distance: 0.33m)
#     Agent 1042 assigned to Lane 165 (distance: 0.19m)
#     Agent 1044 assigned to Lane 239 (distance: 0.41m)
#     Agent 1045 assigned to Lane 342 (distance: 0.31m)
#     Agent 1046 assigned to Lane 249 (distance: 0.18m)
#     Agent 1051 assigned to Lane 255 (distance: 0.32m)
#     Agent 1052 assigned to Lane 166 (distance: 0.21m)
#     Agent 1053 assigned to Lane 292 (distance: 1.84m)
#     Agent 1056 assigned to Lane 259 (distance: 0.21m)
#     Agent 1057 assigned to Lane 239 (distance: 0.31m)
#     Agent 1058 assigned to Lane 276 (distance: 0.56m)
#     Agent 1060 assigned to Lane 343 (distance: 0.08m)
#     Agent 1080 assigned to Lane 254 (distance: 0.67m)
#     Agent 1017 assigned to Lane 255 (distance: 0.39m)
#     Agent 1018 assigned to Lane 342 (distance: 0.11m)
#     Agent 1019 assigned to Lane 255 (distance: 0.24m)
#     Agent 1020 assigned to Lane 388 (distance: 0.03m)
#     Agent 1021 assigned to Lane 255 (distance: 0.08m)
#     Agent 1089 assigned to Lane 342 (distance: 0.12m)
#   Scenario 946519875ae5fde8: Assigning agents to lanes...
#     Agent 2177 assigned to Lane 135 (distance: 0.05m)
#     Agent 2179 assigned to Lane 203 (distance: 0.85m)
#     Agent 2186 assigned to Lane 200 (distance: 0.58m)
#     Agent 2187 assigned to Lane 135 (distance: 0.08m)
#     Agent 2188 assigned to Lane 135 (distance: 0.02m)
#     Agent 2189 assigned to Lane 135 (distance: 0.13m)
#     Agent 2190 assigned to Lane 202 (distance: 0.30m)
#     Agent 2191 assigned to Lane 203 (distance: 0.08m)
#     Agent 2192 assigned to Lane 216 (distance: 0.56m)
#     Agent 2175 assigned to Lane 203 (distance: 0.02m)
#     Agent 2514 assigned to Lane 135 (distance: 0.12m)
#   Scenario 5cdf72917859993b: Assigning agents to lanes...
#     Agent 411 assigned to Lane 672 (distance: 0.21m)
#     Agent 412 assigned to Lane 679 (distance: 1.26m)
#     Agent 413 assigned to Lane 679 (distance: 0.16m)
#     Agent 414 assigned to Lane 273 (distance: 0.12m)
#     Agent 416 assigned to Lane 288 (distance: 0.37m)
#     Agent 417 assigned to Lane 333 (distance: 0.19m)
#     Agent 419 assigned to Lane 290 (distance: 0.75m)
#     Agent 421 assigned to Lane 678 (distance: 0.22m)
#     Agent 422 assigned to Lane 679 (distance: 0.07m)
#     Agent 423 assigned to Lane 289 (distance: 0.09m)
#     Agent 426 assigned to Lane 679 (distance: 0.08m)
#     Agent 430 assigned to Lane 672 (distance: 0.22m)
#     Agent 431 assigned to Lane 679 (distance: 0.09m)
# KeyboardInterrupt
